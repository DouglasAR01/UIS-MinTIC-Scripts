# %%
import pandas as pd

# %% [markdown]
# # CONFIGURACIÓN

# %%
# 1. Comportamiento:
LIMITE_POR_GRUPO = 70
TOLERANCIA = 5
TOLERANCIA_ACTIVADA = True
NUMERO_GRUPOS = 74
CURSO_HORA_SIN_ASIGNAR = 'Sin asignar' # Si queda algún grupo sin asignarle horario
GENERACION_CURSOS_AUTOMATICA = False # Si se establece como False es necesario poner el número de grupos manualmente más abajo
JORNADAS_AUTOMATICAS = False # Si se establece como False es necesario poner la distribución por jornadas manualmente más abajo
# Estrategias existentes: BALANCEADO_PURO, LLENAR
ESTRATEGIA = 'LLENAR' 

# 2. Toma de datos:
COLUMNA_DISP_PROGRAMACION = 'DISP_PROGRAMACION'
COLUMNA_DISP_INGLES = 'DISP_INGLES'
COLUMNA_DISP_COACH = 'DISP_COACHING'
COLUMNA_NIVEL_ESTUDIO = 'NIVEL_EDUCATIVO_AGRUPADO'
COLUMNA_CODIGO = 'CODIGO'

# x. Configuración de columnas de archivo de cambios de horario
COLUMNAS_CAMBIOS_HORARIO = {
    'DOCUMENTO': 'Cédula del estudiante',
    COLUMNA_CODIGO: 'Código del estudiante',
    COLUMNA_DISP_PROGRAMACION: 'Horarios disponibles de PROGRAMACIÓN',
    COLUMNA_DISP_INGLES: 'Horarios disponibles INGLÉS',
    COLUMNA_DISP_COACH: 'Horarios disponibles COACH'
}


# x. Asignaturas a tener en cuenta. 
#    Formato: nombre (llave) => código de sistema académico, tipo (1 para horario unido, 2 para granular).
ASIGNATURAS = {
    'JAVA': {
        'codigo': 'H',
        'tipo': 1        
    },
    'INGLES 2': {
        'codigo': 'M',
        'tipo': 2
    },
    'COACH 2': {
        'codigo': 'N',
        'tipo': 2
    }
}

# x. Codificación de los horarios. Estos deben de coincidir en el formato con el que se alimenta el software.
#    Franjas unidas se us
FRANJAS_UNIDAS = {
    'MAÑANA': [
        'Jornada de la mañana (6 a.m. a 8 a.m.)',
        'Jornada de la mañana (8 a.m. a 10 a.m.)',
        'Jornada de la mañana (10 a.m. a 12 m.)'
    ],
    'TARDE': [        
        'Jornada de la tarde (12 m. a 2 p.m.)',
        'Jornada de la tarde (2 p.m. a 4 p.m.)',
        'Jornada de la tarde (4 p.m. a 6 p.m.)'
    ],
    'NOCHE': [
        'Jornada de la noche (6 p.m. a 8 p.m.)',
        'Jornada de la noche (8 p.m. a 10 p.m.)'
    ]
}

FRANJAS_GRANULARES = {
    'MAÑANA' : [        
        'Jornada de la mañana (6 a.m. a 7 a.m.)',
        'Jornada de la mañana (7 a.m. a 8 a.m.)',
        'Jornada de la mañana (8 a.m. a 9 a.m.)',
        'Jornada de la mañana (9 a.m. a 10 a.m.)',
        'Jornada de la mañana (10 a.m. a 11 a.m.)',
        'Jornada de la mañana (11 a.m. a 12 m.)'
    ],
    'TARDE': [
        'Jornada de la tarde (12 m. a 1 p.m.)',
        'Jornada de la tarde (1 p.m. a 2 p.m.)',
        'Jornada de la tarde (2 p.m. a 3 p.m.)',
        'Jornada de la tarde (3 p.m. a 4 p.m.)',
        'Jornada de la tarde (4 p.m. a 5 p.m.)',
        'Jornada de la tarde (5 p.m. a 6 p.m.)',
    ],
    'NOCHE': [
        'Jornada de la noche (6 p.m. a 7 p.m.)',
        'Jornada de la noche (7 p.m. a 8 p.m.)',
        'Jornada de la noche (8 p.m. a 9 p.m.)',
        'Jornada de la noche (9 p.m. a 10 p.m.)'
    ]
}

# x. Número de grupos por jornada. Debe de coincidir con el número de grupos a crear.
#    Este campo permite cambiar la distribución de los grupos en las jornadas.
JORNADAS = {
    'MAÑANA': 22,
    'TARDE': 12,
    'NOCHE': 36
}

JORNADAS_MANUALES = {
    'JAVA': { #69
        'MAÑANA': 20,
        'TARDE': 12,
        'NOCHE': 37
    },
    'INGLES 2': { #64
        'MAÑANA': 19,
        'TARDE': 17,
        'NOCHE': 28
    },
    'COACH 2': { #74
        'MAÑANA': 22, #
        'TARDE': 25,
        'NOCHE': 27
    }
}

# x. Número de grupos manuales. El tipo de franja horaria debe de coincidir con el definido en ASIGNATURAS.
#    Debe existir un diccionario por asignatura que contenga cada jornada, la cual contiene una lista de tuplas.
#    Donde el primer elemento es la franja horaria y el segundo la cantidad.
#    Para estimar la cantidad de grupos se puede usar el Script Indagador. Los grupos deben de coincidir con la
#    distribución definida (ya sea que esté en automático o manual)

CURSOS_MANUALES = {
    'JAVA': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 8 a.m.)', 8),
            ('Jornada de la mañana (8 a.m. a 10 a.m.)', 8),
            ('Jornada de la mañana (10 a.m. a 12 m.)', 4)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 2 p.m.)', 3),
            ('Jornada de la tarde (2 p.m. a 4 p.m.)', 4),
            ('Jornada de la tarde (4 p.m. a 6 p.m.)', 5)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 8 p.m.)', 18),
            ('Jornada de la noche (8 p.m. a 10 p.m.)', 19)
        ]
    },
    'INGLES 2': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 7 a.m.)', 5),
            ('Jornada de la mañana (7 a.m. a 8 a.m.)', 5),
            ('Jornada de la mañana (8 a.m. a 9 a.m.)', 0),
            ('Jornada de la mañana (9 a.m. a 10 a.m.)', 5),
            ('Jornada de la mañana (10 a.m. a 11 a.m.)', 0),
            ('Jornada de la mañana (11 a.m. a 12 m.)', 4)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 1 p.m.)', 4),
            ('Jornada de la tarde (1 p.m. a 2 p.m.)', 4),
            ('Jornada de la tarde (2 p.m. a 3 p.m.)', 3),
            ('Jornada de la tarde (3 p.m. a 4 p.m.)', 0),
            ('Jornada de la tarde (4 p.m. a 5 p.m.)', 0),
            ('Jornada de la tarde (5 p.m. a 6 p.m.)', 6)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 7 p.m.)', 6),
            ('Jornada de la noche (7 p.m. a 8 p.m.)', 9),
            ('Jornada de la noche (8 p.m. a 9 p.m.)', 9),
            ('Jornada de la noche (9 p.m. a 10 p.m.)', 4)
        ]
    },
    'COACH 2': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 7 a.m.)', 5),
            ('Jornada de la mañana (7 a.m. a 8 a.m.)', 4),
            ('Jornada de la mañana (8 a.m. a 9 a.m.)', 5),
            ('Jornada de la mañana (9 a.m. a 10 a.m.)', 2),
            ('Jornada de la mañana (10 a.m. a 11 a.m.)', 4),
            ('Jornada de la mañana (11 a.m. a 12 m.)', 2)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 1 p.m.)', 5),
            ('Jornada de la tarde (1 p.m. a 2 p.m.)', 5),
            ('Jornada de la tarde (2 p.m. a 3 p.m.)', 2),
            ('Jornada de la tarde (3 p.m. a 4 p.m.)', 4),
            ('Jornada de la tarde (4 p.m. a 5 p.m.)', 4),
            ('Jornada de la tarde (5 p.m. a 6 p.m.)', 5)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 7 p.m.)', 7),
            ('Jornada de la noche (7 p.m. a 8 p.m.)', 5),
            ('Jornada de la noche (8 p.m. a 9 p.m.)', 6),
            ('Jornada de la noche (9 p.m. a 10 p.m.)', 9)
        ]
    }
}

# %%
ESTUDIANTES_EXCLUIDOS = [
#     # Estudiantes que no entran a ciclo 1
#     2220111, # Fabian David
#     2220135, # Juan Diego
#     2220249, # Farid Jose
#     2220256, # Diego Alejandro
#     2220605, # Miguel Ángel
#     2220755, # Juan David
#     2220841, # Gerson David
#     2221039, # Hector Armando
#     2221575, # Iván Camilo
#     2222796, # Andrés Felipe
#     2223097, # Camilo Andrés
    
#     # Otros estudiantes debajo de esta línea
#     # Estudiantes que no desean continuar
#     2224295, # No está en el consolidado
#     2224297, # No está en el consolidado
#     2224300, # No está en el consolidado
#     2224306, # No está en el consolidado
#     2224320, # No está en el consolidado
#     2224331, # No está en el consolidado
#     2224336, # No está en el consolidado
#     2224400, # No está en el consolidado
#     2224425, # No está en el consolidado
#     2224437, # No está en el consolidado
#     2224450, # No está en el consolidado
#     2224457, # No está en el consolidado
#     2224464, # No está en el consolidado
#     2224477, # No está en el consolidado
#     2224579, # No está en el consolidado
#     2224639, # No está en el consolidado
#     2223233, 
#     2224441, # No está en el consolidado
#     2220474,
]

# %% [markdown]
# # FUNCIONES

# %%
def verificarConfiguracion():
    # Datos cruciales de configuración
    estrategias = [
        'LLENAR',
        'BALANCEADO_PURO'
    ]
    tiposAsignaturas = [1, 2]
    llavesObligatoriasAsignaturas = ['tipo', 'codigo']
    
    # Verificaciones
    if not GENERACION_CURSOS_AUTOMATICA:
        for asignatura, jornadas in CURSOS_MANUALES.items():            
            sumaTotal = 0
            for jornada, listaJornadas in jornadas.items():
                sumaJornada = 0
                for franja, cantidad in listaJornadas:
                    sumaTotal += cantidad
                    if sumaJornada + cantidad > JORNADAS_MANUALES[asignatura][jornada]:
                        raise Exception('Se superó el número de grupos permitido para la jornada', jornada, franja)
                    sumaJornada += cantidad
                if sumaTotal > NUMERO_GRUPOS:
                    print (sumaTotal + sumaJornada)
                    raise Exception('Se superó el número de grupos permitido para la asignatura', asignatura, jornada)
                if sumaJornada != JORNADAS_MANUALES[asignatura][jornada]:
                    raise Exception('Faltan', JORNADAS_MANUALES[asignatura][jornada] - sumaJornada, 'grupos en la jornada', jornada)

# %%
#verificarConfiguracion()
# INICIALIZACIÓN DE DICCIONARIOS AUXILIARES
FRANJAS_PROGRAMACION = {}
FRANJAS_INGLES_COACH = {}
TRADUCTOR_PROGRAMACION = {}
TRADUCTOR_INGLES_COACH = {}
i = 0
for jornada in FRANJAS_GRANULARES.values():
    for franja in jornada:        
        FRANJAS_INGLES_COACH[franja] = i
        TRADUCTOR_INGLES_COACH[i] = franja
        i += 1
i = 0
for jornada in FRANJAS_UNIDAS.values():
    for franja in jornada:
        tupla = (i, i+1)
        FRANJAS_PROGRAMACION[franja] = tupla
        TRADUCTOR_PROGRAMACION[tupla] = franja
        i += 2
FRANJAS_INGLES_COACH['HOMOLOGADO'] = -1
TRADUCTOR_INGLES_COACH[-1] = 'HOMOLOGADO'

# %%
# Se le pasa cada cadena de columna de jornadas, retorna una lista con los códigos de franja
def tokenizarAsignado(cadena, separador, conjunto):
    horas = cadena.split(separador)
    rta = []
    for hora in horas:
        if hora in conjunto:
            rta.append(conjunto[hora])
    return rta
def generarAsignaturasCiclo(asignaturas):
    rta = []
    for asignatura, params in asignaturas.items():
        rta.append((asignatura, params['tipo']))
    return rta
def inicializarCursos(inicio, numero, codigo, jornada, tipo):
    cursos = {}
    if tipo == 1:
        franjas = FRANJAS_UNIDAS[jornada]
    else:
        franjas = FRANJAS_GRANULARES[jornada]
    cantidadFranjas = len(franjas)
    for i in range (inicio, numero):
        nombre = codigo + str(i)
        cursos[nombre] = {}
        cursos[nombre]['cantidad'] = 0
        cursos[nombre]['escolaridad'] = {}
        cursos[nombre]['horario'] = franjas[i % cantidadFranjas] if GENERACION_CURSOS_AUTOMATICA else CURSO_HORA_SIN_ASIGNAR
    return cursos
def inicializarJornadas(asignatura, codigo, tipo):
    num = 1
    jornadas = {}
    conjunto = JORNADAS if JORNADAS_AUTOMATICAS else JORNADAS_MANUALES[asignatura]
    
    for jornada, dist in conjunto.items():
        jornadas[jornada] = inicializarCursos(num, dist + num, codigo, jornada, tipo)
        num += dist        
    return jornadas
def inicializarAsignaturas():
    grupos = {}
    for nombre, datos in ASIGNATURAS.items():
        grupos[nombre] = inicializarJornadas(nombre, datos['codigo'], datos['tipo'])
    return grupos
def asignarHorarios():
    for asignatura, jornadas in CURSOS_MANUALES.items():
        i = 1
        for jornada, lista in jornadas.items():
            prefijoCodigo = ASIGNATURAS[asignatura]['codigo']
            tipo = ASIGNATURAS[asignatura]['tipo']
            for hora, cantidad in lista:
                for j in range (i, cantidad + i):
                    codigo = prefijoCodigo + str(j)
                    GRUPOS[asignatura][jornada][codigo]['horario'] = hora
                    i += 1

# %%
def permutar(listaProgramacion, listaIngles, listaCoach):
    for horaInicio, horaFin in listaProgramacion:
        for horaIngles in listaIngles:
            if horaIngles < horaInicio or horaIngles > horaFin:
                for horaCoach in listaCoach:
                    if horaCoach != horaIngles and (horaCoach < horaInicio or horaCoach > horaFin):
                        return (horaInicio, horaFin), horaIngles, horaCoach
    return -1
def todasPermutaciones(listaProgramacion, listaIngles, listaCoach):
    rta = []
    cant = len(listaProgramacion)
    nuevaLista = listaProgramacion.copy()
    while cant > 0:
        res = permutar(nuevaLista, listaIngles, listaCoach)
        if res != -1:
            rta.append(res)
        nuevaLista.pop(0)
        cant -= 1
    return rta

def determinarHoraTextoCurso(idCurso, tipo):
    if tipo == 1:
        traductor = TRADUCTOR_PROGRAMACION
    else:
        traductor = TRADUCTOR_INGLES_COACH
    
    return traductor[idCurso]

def determinarJornada(idCurso, tipo):
    if tipo == 1:
        conjunto = FRANJAS_UNIDAS
    else:
        conjunto = FRANJAS_GRANULARES
    
    nombreCurso = determinarHoraTextoCurso(idCurso, tipo)
    for jornada in conjunto:        
        if nombreCurso in conjunto[jornada]:
            return jornada

def menorCursoPorCodigo(asignatura, jornada, idCurso, tipo):
    costoMinimo = LIMITE_POR_GRUPO * 2
    nombreCursoMinimo = -1
    ultimo = -1
    horaCursoActual = determinarHoraTextoCurso(idCurso, tipo)
    for codigo, datos in GRUPOS[asignatura][jornada].items():
        if datos['horario'] == horaCursoActual:
            ultimo = codigo
            cantidad = datos['cantidad']
            if cantidad < costoMinimo and cantidad < LIMITE_POR_GRUPO + (TOLERANCIA if TOLERANCIA_ACTIVADA else 0):
                costoMinimo = cantidad
                nombreCursoMinimo = codigo
    if nombreCursoMinimo == -1:
        raise Exception('Los cursos de la asignatura', asignatura, 'en el horario', horaCursoActual, 'están llenos.', 'Último grupo intentado:', ultimo)
    return nombreCursoMinimo, costoMinimo

# Debe de llegarle una lista de asignaturas con un mapeado a modo de tupla (nombreAsignatura, tipo) que sea de igual
# longitud que la tupla emparejamientos
def menorCostoCurso(asignaturas, emparejamientos):
    costoMinimo = 100000
    codigosMinimos = -1
    jornadasMinimas = -1
    emparejamientoMinimo = -1
    for emparejamiento in emparejamientos:
        i = 0        
        costoActual = 0
        codigos = []
        jornadas = []
        for idCurso in emparejamiento:
            nombreAsignatura, tipoAsignatura = asignaturas[i]
            jornada = determinarJornada(idCurso, tipoAsignatura)
            codigoCurso, costo = menorCursoPorCodigo(nombreAsignatura, jornada, idCurso, tipoAsignatura)
            costoActual += costo
            jornadas.append(jornada)
            codigos.append(codigoCurso)
            i += 1
        if costoActual < costoMinimo:
            costoMinimo = costoActual
            codigosMinimos = codigos
            jornadasMinimas = jornadas
            emparejamientoMinimo = emparejamiento
    return codigosMinimos, jornadasMinimas, emparejamientoMinimo

def buscarCursoSinLlenar(asignatura, jornada, idCurso, tipo):
    cursosValidosLlenos = []
    horaCursoActual = determinarHoraTextoCurso(idCurso, tipo)
    for codigo, datos in GRUPOS[asignatura][jornada].items():
        if datos['horario'] == horaCursoActual:            
            if datos['cantidad'] < LIMITE_POR_GRUPO:
                return codigo, horaCursoActual
            else:
                cursosValidosLlenos.append((codigo, horaCursoActual, datos['cantidad']))
    if TOLERANCIA_ACTIVADA:
        for codigo, hora, cantidad in cursosValidosLlenos:
            if cantidad < LIMITE_POR_GRUPO + TOLERANCIA:
                return codigo, hora
    # Si todos están llenos para la hora buscada, devuelve -1
    return -1, horaCursoActual         
    
def asignamientoNaive(asignaturas, emparejamientos):
    # [((12, 13), 15, 14)]
    horaCursoActual = -1
    ultimo = -1
    for emparejamiento in emparejamientos:
        # ((12, 13), 15, 14)
        i = 0
        codigos = []
        jornadas = []
        for idCurso in emparejamiento:
            # (12,13)
            if type(idCurso) != tuple and idCurso < 0:
                codigos.append('HOMOLOGADO')
                jornadas.append('HOMOLOGADO')
                i += 1
                continue
            nombreAsignatura, tipoAsignatura = asignaturas[i]
            jornada = determinarJornada(idCurso, tipoAsignatura)
            codigo, horaCursoActual = buscarCursoSinLlenar(nombreAsignatura, jornada, idCurso, tipoAsignatura)
            if codigo == -1:
                ultimo = nombreAsignatura
                break
            codigos.append(codigo)
            jornadas.append(jornada)
            i += 1
        if len(codigos) == 3:
            return codigos, jornadas, emparejamiento
    if len(emparejamientos) > 0:        
        raise Exception('Todos los cursos para el horario ', horaCursoActual, 'están llenos. Última asignatura analizada: ', ultimo)
    return -1, horaCursoActual, ultimo

# %% [markdown]
# # Lectura de datos

# %%
DATOS_PRECARGA = pd.read_excel('./INPUT/GRUPOS/CONSOLIDADO_PRECARGA_CICLO2.xlsx', engine='openpyxl')
DATOS_FASE2 = pd.read_excel('./INPUT/GRUPOS/CONSOLIDADO_EST_CICLO2.xlsx', engine='openpyxl')

# %%
# DATOS_CAMBIO = pd.read_excel('./INPUT/GRUPOS/CAMBIOS_HORARIO.xlsx', engine='openpyxl')
# DATOS_CAMBIO = DATOS_CAMBIO[COLUMNAS_CAMBIOS_HORARIO.values()]

# %%
# print('Estudiantes totales en el consolidado:', len(DATOS))
# print('Estudiantes exclucidos:', len(ESTUDIANTES_EXCLUIDOS))
# print('Total estudiantes a procesar:', len(DATOS)-len(ESTUDIANTES_EXCLUIDOS))

# %%
DATOS_PRECARGA[DATOS_PRECARGA['CODIGO'] == 2222367]
# Out:
#     DOCUMENTO   CODIGO         NOMBRE         APELLIDO TELEFONO_MINTIC  \
# 0  1118558984  2222367  DANIEL ISAIAS  VILLEGAS PINZON      3104817797
#
#    TELEFONO_FORMULARIO  TELEFONO_SISTEMA_ACADEMICO  \
# 0         3.104818e+09                3.104818e+09
#
#                         EMAIL                       DISP_PROGRAMACION  \
# 0  dannielvillegasp@gmail.com  Jornada de la mañana (6 a.m. a 8 a.m.)
#
#                                DISP_INGLES  \
# 0  Jornada de la mañana (9 a.m. a 10 a.m.)
#
#                           DISP_COACHING TRAB_COLABORATIVO  \
# 0  Jornada de la tarde (12 m. a 1 p.m.)         NO APLICA
#
#   NIVEL_EDUCATIVO_AGRUPADO  PRECARGA  SOLICITA_CAMBIO  CAMBIO_EFECTUADO
# 0                BACHILLER      True            False             False

# %% [markdown]
# ## Demostración de permutación

# %%
# Test de permutación
# Se asume que todas las materias se ven una vez por día
# Programación 2 horas día
# Inglés 1 hora día
# Coach 1 hora día
ip = 0
programacion = tokenizarAsignado(DATOS_FASE2[COLUMNA_DISP_PROGRAMACION][ip], ';', FRANJAS_PROGRAMACION)
ingles = tokenizarAsignado(DATOS_FASE2[COLUMNA_DISP_INGLES][ip], ';', FRANJAS_INGLES_COACH)
coach = tokenizarAsignado(DATOS_FASE2[COLUMNA_DISP_COACH][ip], ';', FRANJAS_INGLES_COACH)
print (programacion)
print (ingles)
print (coach)
# Out:
# [(8, 9), (10, 11)]
# [7, 12]
# [13, 14]

# %%
DATOS_FASE2.iloc[0]
# Out:
# DOCUMENTO                                                            1010149854
# CODIGO                                                                  2223105
# NOMBRE                                                             PAOLA ANDREA
# APELLIDO                                                              ASIS POLO
# TELEFONO_MINTIC                                                    3007911909.0
# TELEFONO_FORMULARIO                                                3007911909.0
# TELEFONO_SISTEMA_ACADEMICO                                           3007911909
# EMAIL                                                   paolaasispolo@gmail.com
# DISP_PROGRAMACION             Jornada de la tarde (2 p.m. a 4 p.m.);Jornada ...
# DISP_INGLES                   Jornada de la tarde (1 p.m. a 2 p.m.);Jornada ...
# DISP_COACHING                 Jornada de la noche (7 p.m. a 8 p.m.);Jornada ...
# TRAB_COLABORATIVO                                                     NO APLICA
# NIVEL_EDUCATIVO_AGRUPADO                                           PROFESIONAL+
# PRECARGA                                                                  False
# SOLICITA_CAMBIO                                                            True
# CAMBIO_EFECTUADO                                                           True
# Name: 0, dtype: object

# %%
permutar(programacion, ingles, coach)
# Out:
# ((8, 9), 7, 13)

# %%
todasPermutaciones(programacion, ingles, coach)
# Out:
# [((8, 9), 7, 13), ((10, 11), 7, 13)]

# %% [markdown]
# # PROCESAMIENTO

# %%
def generarAsignaciones(dfDatos, infoCiclo, permitirOrganizar = False, permitirCambios = False, separarDiscapacitados = False):
    columnaProgramacion = []
    columnaIngles = []
    columnaCoach = []
    copiaDatos = dfDatos.copy()
    if permitirCambios:
        estudiantesConCambios = DATOS_CAMBIO[COLUMNAS_CAMBIOS_HORARIO['CODIGO']].values
    if ESTRATEGIA == 'LLENAR' and permitirOrganizar:
        copiaDatos.sort_values(by=[COLUMNA_NIVEL_ESTUDIO], inplace = True, ignore_index = True)
    for index, row in copiaDatos.iterrows():
        codigoEst = row[COLUMNA_CODIGO]
        if codigoEst in ESTUDIANTES_EXCLUIDOS:
            ESTADISTICAS_PROCESADO['totalesExcluidos'] += 1
            columnaProgramacion.append('EXCLUIDO')
            columnaIngles.append('EXCLUIDO')
            columnaCoach.append('EXCLUIDO')
            continue
        if separarDiscapacitados and row['DISCAPACIDAD'] == 'Si':
            ESTADISTICAS_PROCESADO['totalesDiscapacitados'] += 1
            columnaProgramacion.append('DISCAPACITADO')
            columnaIngles.append('DISCAPACITADO')
            columnaCoach.append('DISCAPACITADO')
            continue
        if permitirCambios and codigoEst in estudiantesConCambios:
            estudianteCambiar = DATOS_CAMBIO[DATOS_CAMBIO[COLUMNAS_CAMBIOS_HORARIO['CODIGO']] == codigoEst]
            listaProgramacion = tokenizarAsignado(estudianteCambiar[COLUMNAS_CAMBIOS_HORARIO[COLUMNA_DISP_PROGRAMACION]].values[0], ';', FRANJAS_PROGRAMACION)
            listaIngles = tokenizarAsignado(estudianteCambiar[COLUMNAS_CAMBIOS_HORARIO[COLUMNA_DISP_INGLES]].values[0], ';', FRANJAS_INGLES_COACH)
            listaCoach = tokenizarAsignado(estudianteCambiar[COLUMNAS_CAMBIOS_HORARIO[COLUMNA_DISP_COACH]].values[0], ';', FRANJAS_INGLES_COACH)
        else:        
            listaProgramacion = tokenizarAsignado(row[COLUMNA_DISP_PROGRAMACION], ';', FRANJAS_PROGRAMACION)
            listaIngles = tokenizarAsignado(row[COLUMNA_DISP_INGLES], ';', FRANJAS_INGLES_COACH)
            listaCoach = tokenizarAsignado(row[COLUMNA_DISP_COACH], ';', FRANJAS_INGLES_COACH)
        permutaciones = todasPermutaciones(listaProgramacion, listaIngles, listaCoach)
        if ESTRATEGIA == 'BALANCEADO_PURO':        
            cursos, jornadas, _ = menorCostoCurso(infoCiclo, permutaciones)
        elif ESTRATEGIA == 'LLENAR':
            cursos, jornadas, _ = asignamientoNaive(infoCiclo, permutaciones)
        if cursos != -1:
            i = 0
            for asignatura, tipo in infoCiclo:
                if jornadas[i] != 'HOMOLOGADO':
                    GRUPOS[asignatura][jornadas[i]][cursos[i]]['cantidad'] += 1
                    nivelEstudio = row[COLUMNA_NIVEL_ESTUDIO]
                    if nivelEstudio in GRUPOS[asignatura][jornadas[i]][cursos[i]]['escolaridad']:
                        GRUPOS[asignatura][jornadas[i]][cursos[i]]['escolaridad'][nivelEstudio] += 1
                    else:
                        GRUPOS[asignatura][jornadas[i]][cursos[i]]['escolaridad'][nivelEstudio] = 1            
                i += 1
            codigoProgramacion, codigoIngles, codigoCoach = cursos
            columnaProgramacion.append(codigoProgramacion)
            columnaIngles.append(codigoIngles)
            columnaCoach.append(codigoCoach)
            ESTADISTICAS_PROCESADO['totalesInscritos'] += 1
        else:
            columnaProgramacion.append('CRUCE')
            columnaIngles.append('CRUCE')
            columnaCoach.append('CRUCE')
            ESTADISTICAS_PROCESADO['totalesIncorrectos'] += 1
        ESTADISTICAS_PROCESADO['totales'] += 1
    return columnaProgramacion, columnaIngles, columnaCoach

# %%
# Refactorización a función
INFO_CICLO = generarAsignaturasCiclo(ASIGNATURAS)
GRUPOS = inicializarAsignaturas()
if not GENERACION_CURSOS_AUTOMATICA:
    asignarHorarios()
ESTADISTICAS_PROCESADO = {
    'totales' : 0,
    'totalesInscritos' : 0,
    'totalesIncorrectos' : 0,
    'totalesExcluidos' : 0,
    'totalesDiscapacitados' : 0 
}
colProgF1, colIngF1, colCoachF1 = generarAsignaciones(DATOS_PRECARGA, INFO_CICLO, permitirOrganizar = False, permitirCambios = False, separarDiscapacitados = False)
colProgF2, colIngF2, colCoachF2 = generarAsignaciones(DATOS_FASE2, INFO_CICLO, permitirOrganizar = True, permitirCambios = False, separarDiscapacitados = False)

# %%
ESTADISTICAS_PROCESADO['totales']
# Out:
# 4679

# %% [markdown]
# # RESULTADOS

# %%
for asignatura, jornadas in GRUPOS.items():
    print ('========')
    print (asignatura)
    for jornada, cursos in jornadas.items():
        print ('======>', jornada)
        for curso, datos in cursos.items():
            print (curso, datos['horario'], datos['cantidad'], datos['escolaridad'])
# Out:
# ========
# JAVA
# ======> MAÑANA
# H1 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'BACHILLER': 58, 'PROFESIONAL+': 8, 'TÉCNICO': 4}
# H2 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'BACHILLER': 20, 'PROFESIONAL+': 30, 'TÉCNICO': 20}
# H3 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 42, 'TÉCNICO': 23, 'BACHILLER': 4, 'DESCONOCIDO': 1}
# H4 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'TÉCNICO': 37, 'BACHILLER': 15, 'PROFESIONAL+': 18}
# H5 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 24, 'TÉCNICO': 9, 'BACHILLER': 26, 'DESCONOCIDO': 11}
# H6 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'BACHILLER': 62, 'PROFESIONAL+': 8}
# H7 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 70}
# H8 Jornada de la mañana (6 a.m. a 8 a.m.) 57 {'PROFESIONAL+': 1, 'TÉCNICO': 56}
# H9 Jornada de la mañana (8 a.m. a 10 a.m.) 74 {'BACHILLER': 48, 'TÉCNICO': 14, 'PROFESIONAL+': 12}
# H10 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'BACHILLER': 44, 'TÉCNICO': 7, 'PROFESIONAL+': 19}
# H11 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'BACHILLER': 13, 'TÉCNICO': 8, 'PROFESIONAL+': 49}
# H12 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'TÉCNICO': 44, 'PROFESIONAL+': 13, 'BACHILLER': 13}
# H13 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'BACHILLER': 37, 'TÉCNICO': 16, 'PROFESIONAL+': 17}
# H14 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'BACHILLER': 70}
# H15 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'BACHILLER': 11, 'PROFESIONAL+': 59}
# H16 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'PROFESIONAL+': 26, 'TÉCNICO': 44}
# H17 Jornada de la mañana (10 a.m. a 12 m.) 75 {'TÉCNICO': 13, 'BACHILLER': 43, 'PROFESIONAL+': 19}
# H18 Jornada de la mañana (10 a.m. a 12 m.) 75 {'PROFESIONAL+': 34, 'TÉCNICO': 26, 'BACHILLER': 15}
# H19 Jornada de la mañana (10 a.m. a 12 m.) 74 {'BACHILLER': 31, 'PROFESIONAL+': 17, 'TÉCNICO': 21, 'DESCONOCIDO': 5}
# H20 Jornada de la mañana (10 a.m. a 12 m.) 70 {'BACHILLER': 31, 'PROFESIONAL+': 33, 'TÉCNICO': 6}
# ======> TARDE
# H21 Jornada de la tarde (12 m. a 2 p.m.) 70 {'BACHILLER': 20, 'PROFESIONAL+': 31, 'TÉCNICO': 19}
# H22 Jornada de la tarde (12 m. a 2 p.m.) 70 {'PROFESIONAL+': 25, 'BACHILLER': 31, 'TÉCNICO': 13, 'DESCONOCIDO': 1}
# H23 Jornada de la tarde (12 m. a 2 p.m.) 38 {'PROFESIONAL+': 21, 'TÉCNICO': 17}
# H24 Jornada de la tarde (2 p.m. a 4 p.m.) 70 {'BACHILLER': 32, 'PROFESIONAL+': 24, 'TÉCNICO': 14}
# H25 Jornada de la tarde (2 p.m. a 4 p.m.) 70 {'PROFESIONAL+': 24, 'TÉCNICO': 24, 'BACHILLER': 22}
# H26 Jornada de la tarde (2 p.m. a 4 p.m.) 70 {'BACHILLER': 46, 'DESCONOCIDO': 1, 'PROFESIONAL+': 23}
# H27 Jornada de la tarde (2 p.m. a 4 p.m.) 40 {'PROFESIONAL+': 13, 'TÉCNICO': 27}
# H28 Jornada de la tarde (4 p.m. a 6 p.m.) 70 {'BACHILLER': 39, 'PROFESIONAL+': 24, 'TÉCNICO': 7}
# H29 Jornada de la tarde (4 p.m. a 6 p.m.) 70 {'BACHILLER': 15, 'PROFESIONAL+': 28, 'TÉCNICO': 27}
# H30 Jornada de la tarde (4 p.m. a 6 p.m.) 70 {'PROFESIONAL+': 16, 'TÉCNICO': 8, 'BACHILLER': 46}
# H31 Jornada de la tarde (4 p.m. a 6 p.m.) 70 {'BACHILLER': 18, 'DESCONOCIDO': 1, 'PROFESIONAL+': 46, 'TÉCNICO': 5}
# H32 Jornada de la tarde (4 p.m. a 6 p.m.) 25 {'TÉCNICO': 25}
# ======> NOCHE
# H33 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 47, 'TÉCNICO': 10, 'PROFESIONAL+': 13}
# H34 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 53, 'PROFESIONAL+': 11, 'TÉCNICO': 6}
# H35 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 32, 'PROFESIONAL+': 35, 'TÉCNICO': 3}
# H36 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 27, 'TÉCNICO': 16, 'BACHILLER': 27}
# H37 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 67, 'TÉCNICO': 2, 'BACHILLER': 1}
# H38 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 68, 'TÉCNICO': 1, 'BACHILLER': 1}
# H39 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 13, 'TÉCNICO': 55, 'BACHILLER': 2}
# H40 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 20, 'BACHILLER': 12, 'TÉCNICO': 38}
# H41 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 11, 'TÉCNICO': 40, 'PROFESIONAL+': 19}
# H42 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 27, 'PROFESIONAL+': 34, 'TÉCNICO': 9}
# H43 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'TÉCNICO': 24, 'BACHILLER': 16, 'PROFESIONAL+': 30}
# H44 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 45, nan: 1, 'TÉCNICO': 11, 'PROFESIONAL+': 13}
# H45 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 70}
# H46 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 29, 'DESCONOCIDO': 2, 'PROFESIONAL+': 39}
# H47 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 70}
# H48 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 70}
# H49 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'TÉCNICO': 70}
# H50 Jornada de la noche (6 p.m. a 8 p.m.) 54 {'TÉCNICO': 54}
# H51 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 10, 'BACHILLER': 53, 'TÉCNICO': 7}
# H52 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 40, 'PROFESIONAL+': 26, 'TÉCNICO': 4}
# H53 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 31, 'TÉCNICO': 20, 'BACHILLER': 19}
# H54 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 66, 'BACHILLER': 4}
# H55 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 38, 'TÉCNICO': 25, 'BACHILLER': 7}
# H56 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'TÉCNICO': 54, 'BACHILLER': 6, 'PROFESIONAL+': 10}
# H57 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'TÉCNICO': 22, 'BACHILLER': 28, 'PROFESIONAL+': 20}
# H58 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 20, 'TÉCNICO': 32, 'BACHILLER': 18}
# H59 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 29, 'TÉCNICO': 21, 'BACHILLER': 20}
# H60 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'TÉCNICO': 23, 'PROFESIONAL+': 26, 'BACHILLER': 21}
# H61 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'TÉCNICO': 11, 'PROFESIONAL+': 15, 'BACHILLER': 44}
# H62 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 70}
# H63 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 70}
# H64 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 12, 'DESCONOCIDO': 1, 'PROFESIONAL+': 57}
# H65 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 70}
# H66 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 70}
# H67 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 9, 'TÉCNICO': 61}
# H68 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'TÉCNICO': 70}
# H69 Jornada de la noche (8 p.m. a 10 p.m.) 37 {'TÉCNICO': 37}
# ========
# INGLES 2
# ======> MAÑANA
# M1 Jornada de la mañana (6 a.m. a 7 a.m.) 75 {'PROFESIONAL+': 24, 'BACHILLER': 31, 'TÉCNICO': 20}
# M2 Jornada de la mañana (6 a.m. a 7 a.m.) 73 {'PROFESIONAL+': 45, 'TÉCNICO': 20, 'BACHILLER': 8}
# M3 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'PROFESIONAL+': 30, 'TÉCNICO': 28, 'BACHILLER': 12}
# M4 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'TÉCNICO': 4, 'PROFESIONAL+': 16, 'BACHILLER': 50}
# M5 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'PROFESIONAL+': 42, 'TÉCNICO': 28}
# M6 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'BACHILLER': 35, 'PROFESIONAL+': 18, 'TÉCNICO': 17}
# M7 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'TÉCNICO': 16, 'BACHILLER': 21, 'PROFESIONAL+': 33}
# M8 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'TÉCNICO': 18, 'BACHILLER': 28, 'PROFESIONAL+': 24}
# M9 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'BACHILLER': 29, 'DESCONOCIDO': 1, 'PROFESIONAL+': 40}
# M10 Jornada de la mañana (7 a.m. a 8 a.m.) 46 {'PROFESIONAL+': 12, 'TÉCNICO': 34}
# M11 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'BACHILLER': 41, 'TÉCNICO': 10, 'PROFESIONAL+': 19}
# M12 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'BACHILLER': 26, 'PROFESIONAL+': 24, 'TÉCNICO': 20}
# M13 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'TÉCNICO': 17, 'PROFESIONAL+': 10, 'BACHILLER': 43}
# M14 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'BACHILLER': 22, 'PROFESIONAL+': 37, 'TÉCNICO': 11}
# M15 Jornada de la mañana (9 a.m. a 10 a.m.) 18 {'TÉCNICO': 18}
# M16 Jornada de la mañana (11 a.m. a 12 m.) 70 {'PROFESIONAL+': 25, 'BACHILLER': 33, 'TÉCNICO': 12}
# M17 Jornada de la mañana (11 a.m. a 12 m.) 70 {'PROFESIONAL+': 20, 'TÉCNICO': 27, 'BACHILLER': 22, 'DESCONOCIDO': 1}
# M18 Jornada de la mañana (11 a.m. a 12 m.) 70 {'BACHILLER': 48, 'TÉCNICO': 5, 'PROFESIONAL+': 7, 'DESCONOCIDO': 10}
# M19 Jornada de la mañana (11 a.m. a 12 m.) 64 {'BACHILLER': 5, 'DESCONOCIDO': 1, 'PROFESIONAL+': 35, 'TÉCNICO': 23}
# ======> TARDE
# M20 Jornada de la tarde (12 m. a 1 p.m.) 70 {'BACHILLER': 22, 'TÉCNICO': 14, 'PROFESIONAL+': 34}
# M21 Jornada de la tarde (12 m. a 1 p.m.) 70 {'TÉCNICO': 24, 'PROFESIONAL+': 33, 'BACHILLER': 13}
# M22 Jornada de la tarde (12 m. a 1 p.m.) 70 {'TÉCNICO': 10, 'PROFESIONAL+': 19, 'BACHILLER': 41}
# M23 Jornada de la tarde (12 m. a 1 p.m.) 65 {'PROFESIONAL+': 31, 'TÉCNICO': 34}
# M24 Jornada de la tarde (1 p.m. a 2 p.m.) 75 {'BACHILLER': 27, 'TÉCNICO': 22, 'PROFESIONAL+': 26}
# M25 Jornada de la tarde (1 p.m. a 2 p.m.) 74 {'BACHILLER': 18, 'PROFESIONAL+': 31, 'TÉCNICO': 25}
# M26 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'PROFESIONAL+': 14, 'TÉCNICO': 12, 'BACHILLER': 44}
# M27 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'BACHILLER': 9, 'DESCONOCIDO': 1, 'PROFESIONAL+': 42, 'TÉCNICO': 18}
# M28 Jornada de la tarde (2 p.m. a 3 p.m.) 70 {'BACHILLER': 29, 'TÉCNICO': 17, 'PROFESIONAL+': 24}
# M29 Jornada de la tarde (2 p.m. a 3 p.m.) 70 {'BACHILLER': 30, 'TÉCNICO': 8, 'PROFESIONAL+': 32}
# M30 Jornada de la tarde (2 p.m. a 3 p.m.) 40 {'PROFESIONAL+': 16, 'TÉCNICO': 24}
# M31 Jornada de la tarde (5 p.m. a 6 p.m.) 73 {'PROFESIONAL+': 22, 'BACHILLER': 31, 'TÉCNICO': 20}
# M32 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'BACHILLER': 26, 'TÉCNICO': 16, 'PROFESIONAL+': 28}
# M33 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'PROFESIONAL+': 26, 'TÉCNICO': 22, 'BACHILLER': 22}
# M34 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'TÉCNICO': 11, 'PROFESIONAL+': 14, 'BACHILLER': 45}
# M35 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'BACHILLER': 39, 'DESCONOCIDO': 2, 'PROFESIONAL+': 29}
# M36 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'PROFESIONAL+': 22, 'TÉCNICO': 48}
# ======> NOCHE
# M37 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 30, 'TÉCNICO': 16, 'PROFESIONAL+': 24}
# M38 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'PROFESIONAL+': 34, 'BACHILLER': 11, 'TÉCNICO': 25}
# M39 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'TÉCNICO': 23, 'BACHILLER': 24, 'PROFESIONAL+': 23}
# M40 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 56, 'PROFESIONAL+': 6, 'TÉCNICO': 3, 'DESCONOCIDO': 5}
# M41 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 6, 'PROFESIONAL+': 44, 'TÉCNICO': 20}
# M42 Jornada de la noche (6 p.m. a 7 p.m.) 15 {'TÉCNICO': 15}
# M43 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 41, 'PROFESIONAL+': 14, 'TÉCNICO': 15}
# M44 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 24, 'PROFESIONAL+': 41, 'TÉCNICO': 5}
# M45 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 26, 'TÉCNICO': 32, 'BACHILLER': 12}
# M46 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 24, 'BACHILLER': 26, 'TÉCNICO': 20}
# M47 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'TÉCNICO': 13, 'BACHILLER': 47, 'PROFESIONAL+': 10}
# M48 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 67, 'DESCONOCIDO': 1, 'PROFESIONAL+': 2}
# M49 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 70}
# M50 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 36, 'TÉCNICO': 34}
# M51 Jornada de la noche (7 p.m. a 8 p.m.) 54 {'TÉCNICO': 54}
# M52 Jornada de la noche (8 p.m. a 9 p.m.) 74 {'BACHILLER': 43, 'PROFESIONAL+': 18, 'TÉCNICO': 13}
# M53 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 24, 'TÉCNICO': 7, 'BACHILLER': 39}
# M54 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'BACHILLER': 6, 'TÉCNICO': 9, 'PROFESIONAL+': 55}
# M55 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'TÉCNICO': 50, 'PROFESIONAL+': 14, 'BACHILLER': 6}
# M56 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 22, 'TÉCNICO': 28, 'BACHILLER': 20}
# M57 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 30, 'BACHILLER': 22, 'TÉCNICO': 17, nan: 1}
# M58 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'BACHILLER': 62, 'PROFESIONAL+': 8}
# M59 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 70}
# M60 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 9, 'TÉCNICO': 61}
# M61 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 14, 'PROFESIONAL+': 28, 'BACHILLER': 28}
# M62 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 26, 'TÉCNICO': 28, 'BACHILLER': 16}
# M63 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 32, 'BACHILLER': 32, 'TÉCNICO': 5, 'DESCONOCIDO': 1}
# M64 Jornada de la noche (9 p.m. a 10 p.m.) 37 {'PROFESIONAL+': 13, 'TÉCNICO': 24}
# ========
# COACH 2
# ======> MAÑANA
# N1 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'BACHILLER': 19, 'PROFESIONAL+': 37, 'TÉCNICO': 14}
# N2 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'PROFESIONAL+': 26, 'TÉCNICO': 24, 'BACHILLER': 20}
# N3 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'BACHILLER': 50, 'PROFESIONAL+': 18, 'TÉCNICO': 2}
# N4 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'PROFESIONAL+': 42, 'TÉCNICO': 28}
# N5 Jornada de la mañana (6 a.m. a 7 a.m.) 16 {'TÉCNICO': 16}
# N6 Jornada de la mañana (7 a.m. a 8 a.m.) 73 {'PROFESIONAL+': 29, 'BACHILLER': 28, 'TÉCNICO': 16}
# N7 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'BACHILLER': 13, 'PROFESIONAL+': 32, 'TÉCNICO': 25}
# N8 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'TÉCNICO': 14, 'BACHILLER': 42, 'PROFESIONAL+': 14}
# N9 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'BACHILLER': 15, 'PROFESIONAL+': 39, 'TÉCNICO': 16}
# N10 Jornada de la mañana (8 a.m. a 9 a.m.) 70 {'PROFESIONAL+': 16, 'BACHILLER': 39, 'TÉCNICO': 15}
# N11 Jornada de la mañana (8 a.m. a 9 a.m.) 70 {'PROFESIONAL+': 29, 'BACHILLER': 20, 'TÉCNICO': 21}
# N12 Jornada de la mañana (8 a.m. a 9 a.m.) 70 {'TÉCNICO': 15, 'BACHILLER': 36, 'PROFESIONAL+': 18, 'DESCONOCIDO': 1}
# N13 Jornada de la mañana (8 a.m. a 9 a.m.) 70 {'BACHILLER': 31, 'PROFESIONAL+': 39}
# N14 Jornada de la mañana (8 a.m. a 9 a.m.) 37 {'PROFESIONAL+': 8, 'TÉCNICO': 29}
# N15 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'PROFESIONAL+': 23, 'TÉCNICO': 16, 'BACHILLER': 19, 'DESCONOCIDO': 12}
# N16 Jornada de la mañana (9 a.m. a 10 a.m.) 46 {'BACHILLER': 13, 'DESCONOCIDO': 2, 'PROFESIONAL+': 16, 'TÉCNICO': 15}
# N17 Jornada de la mañana (10 a.m. a 11 a.m.) 70 {'BACHILLER': 40, 'TÉCNICO': 12, 'PROFESIONAL+': 18}
# N18 Jornada de la mañana (10 a.m. a 11 a.m.) 70 {'PROFESIONAL+': 27, 'TÉCNICO': 23, 'BACHILLER': 20}
# N19 Jornada de la mañana (10 a.m. a 11 a.m.) 70 {'PROFESIONAL+': 29, 'BACHILLER': 37, 'TÉCNICO': 4}
# N20 Jornada de la mañana (10 a.m. a 11 a.m.) 23 {'PROFESIONAL+': 3, 'TÉCNICO': 20}
# N21 Jornada de la mañana (11 a.m. a 12 m.) 70 {'PROFESIONAL+': 21, 'BACHILLER': 33, 'TÉCNICO': 16}
# N22 Jornada de la mañana (11 a.m. a 12 m.) 25 {'BACHILLER': 1, 'PROFESIONAL+': 13, 'TÉCNICO': 11}
# ======> TARDE
# N23 Jornada de la tarde (12 m. a 1 p.m.) 70 {'BACHILLER': 28, 'PROFESIONAL+': 30, 'TÉCNICO': 12}
# N24 Jornada de la tarde (12 m. a 1 p.m.) 70 {'PROFESIONAL+': 29, 'BACHILLER': 23, 'TÉCNICO': 18}
# N25 Jornada de la tarde (12 m. a 1 p.m.) 70 {'BACHILLER': 45, 'TÉCNICO': 9, 'PROFESIONAL+': 16}
# N26 Jornada de la tarde (12 m. a 1 p.m.) 70 {'BACHILLER': 4, 'PROFESIONAL+': 50, 'TÉCNICO': 16}
# N27 Jornada de la tarde (12 m. a 1 p.m.) 21 {'TÉCNICO': 21}
# N28 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'BACHILLER': 28, 'TÉCNICO': 22, 'PROFESIONAL+': 20}
# N29 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'BACHILLER': 17, 'PROFESIONAL+': 34, 'TÉCNICO': 19}
# N30 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'TÉCNICO': 26, 'PROFESIONAL+': 23, 'BACHILLER': 21}
# N31 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'BACHILLER': 29, 'PROFESIONAL+': 41}
# N32 Jornada de la tarde (1 p.m. a 2 p.m.) 41 {'PROFESIONAL+': 8, 'TÉCNICO': 33}
# N33 Jornada de la tarde (2 p.m. a 3 p.m.) 70 {'TÉCNICO': 20, 'PROFESIONAL+': 29, 'BACHILLER': 21}
# N34 Jornada de la tarde (2 p.m. a 3 p.m.) 68 {'BACHILLER': 28, 'TÉCNICO': 21, 'PROFESIONAL+': 19}
# N35 Jornada de la tarde (3 p.m. a 4 p.m.) 70 {'BACHILLER': 37, 'PROFESIONAL+': 19, 'TÉCNICO': 14}
# N36 Jornada de la tarde (3 p.m. a 4 p.m.) 70 {'PROFESIONAL+': 21, 'BACHILLER': 30, 'TÉCNICO': 19}
# N37 Jornada de la tarde (3 p.m. a 4 p.m.) 70 {'PROFESIONAL+': 20, 'BACHILLER': 46, 'TÉCNICO': 4}
# N38 Jornada de la tarde (3 p.m. a 4 p.m.) 29 {'PROFESIONAL+': 11, 'TÉCNICO': 18}
# N39 Jornada de la tarde (4 p.m. a 5 p.m.) 70 {'BACHILLER': 32, 'PROFESIONAL+': 24, 'TÉCNICO': 14}
# N40 Jornada de la tarde (4 p.m. a 5 p.m.) 70 {'BACHILLER': 26, 'PROFESIONAL+': 26, 'TÉCNICO': 18}
# N41 Jornada de la tarde (4 p.m. a 5 p.m.) 70 {'PROFESIONAL+': 28, 'BACHILLER': 38, 'TÉCNICO': 2, 'DESCONOCIDO': 2}
# N42 Jornada de la tarde (4 p.m. a 5 p.m.) 37 {'PROFESIONAL+': 13, 'TÉCNICO': 24}
# N43 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'BACHILLER': 28, 'TÉCNICO': 10, 'PROFESIONAL+': 32}
# N44 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'BACHILLER': 13, 'TÉCNICO': 27, 'PROFESIONAL+': 30}
# N45 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'PROFESIONAL+': 12, 'TÉCNICO': 6, 'BACHILLER': 51, 'DESCONOCIDO': 1}
# N46 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'PROFESIONAL+': 50, 'TÉCNICO': 20}
# N47 Jornada de la tarde (5 p.m. a 6 p.m.) 17 {'TÉCNICO': 17}
# ======> NOCHE
# N48 Jornada de la noche (6 p.m. a 7 p.m.) 75 {'BACHILLER': 34, 'TÉCNICO': 18, 'PROFESIONAL+': 23}
# N49 Jornada de la noche (6 p.m. a 7 p.m.) 72 {'BACHILLER': 33, 'PROFESIONAL+': 35, 'TÉCNICO': 4}
# N50 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'PROFESIONAL+': 24, 'TÉCNICO': 30, 'BACHILLER': 16}
# N51 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'TÉCNICO': 23, 'BACHILLER': 34, 'PROFESIONAL+': 13}
# N52 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 68, 'DESCONOCIDO': 1, 'PROFESIONAL+': 1}
# N53 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'PROFESIONAL+': 70}
# N54 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'PROFESIONAL+': 16, 'TÉCNICO': 54}
# N55 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 25, 'TÉCNICO': 20, 'PROFESIONAL+': 25}
# N56 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 6, 'PROFESIONAL+': 39, 'TÉCNICO': 25}
# N57 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 41, 'PROFESIONAL+': 18, 'TÉCNICO': 11}
# N58 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 27, 'PROFESIONAL+': 43}
# N59 Jornada de la noche (7 p.m. a 8 p.m.) 39 {'PROFESIONAL+': 13, 'TÉCNICO': 26}
# N60 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 25, 'TÉCNICO': 17, 'BACHILLER': 28}
# N61 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'BACHILLER': 21, 'PROFESIONAL+': 36, 'TÉCNICO': 13}
# N62 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'TÉCNICO': 31, 'PROFESIONAL+': 27, 'BACHILLER': 12}
# N63 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 14, 'BACHILLER': 48, 'TÉCNICO': 8}
# N64 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'BACHILLER': 7, 'PROFESIONAL+': 52, 'TÉCNICO': 11}
# N65 Jornada de la noche (8 p.m. a 9 p.m.) 28 {'TÉCNICO': 28}
# N66 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 21, 'BACHILLER': 34, 'TÉCNICO': 15}
# N67 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 7, 'BACHILLER': 39, 'PROFESIONAL+': 24}
# N68 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 49, 'TÉCNICO': 15, 'BACHILLER': 6}
# N69 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 40, 'PROFESIONAL+': 21, 'BACHILLER': 9}
# N70 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 28, 'BACHILLER': 17, 'PROFESIONAL+': 25}
# N71 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 14, 'PROFESIONAL+': 28, 'BACHILLER': 23, nan: 1, 'DESCONOCIDO': 4}
# N72 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'BACHILLER': 46, 'PROFESIONAL+': 24}
# N73 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 52, 'TÉCNICO': 18}
# N74 Jornada de la noche (9 p.m. a 10 p.m.) 42 {'TÉCNICO': 42}

# %%
# Conteo de grupos NO vacíos
contFranja = {}
nivelesEscolaresMaximos = []
nHibridos = 0
for asignatura, jornadas in GRUPOS.items():
    contFranja[asignatura] = {}
    contEst = 0
    for jornada, cursos in jornadas.items():        
        for curso, datos in cursos.items():
            if datos['cantidad'] > 0:
                contEst += datos['cantidad']
                if datos['horario'] in contFranja[asignatura]:
                    contFranja[asignatura][datos['horario']] += 1
                else:
                    contFranja[asignatura][datos['horario']] = 1
                if ASIGNATURAS[asignatura]['tipo'] == 1:                    
                    niveles = [cantidad for cantidad in datos['escolaridad'].values()]
                    indice = max(niveles)/datos['cantidad']
                    nivelesEscolaresMaximos.append(indice)
                    if len(datos['escolaridad']) > 1:
                        nHibridos +=1
                        print (curso, 'Es híbrido con un índice de homogeneidad', indice)
    print ('Total estudiantes en', asignatura, contEst)
print ('Numero de cursos hibridos de programación:', nHibridos)
# Out:
# H1 Es híbrido con un índice de homogeneidad 0.8285714285714286
# H2 Es híbrido con un índice de homogeneidad 0.42857142857142855
# H3 Es híbrido con un índice de homogeneidad 0.6
# H4 Es híbrido con un índice de homogeneidad 0.5285714285714286
# H5 Es híbrido con un índice de homogeneidad 0.37142857142857144
# H6 Es híbrido con un índice de homogeneidad 0.8857142857142857
# H8 Es híbrido con un índice de homogeneidad 0.9824561403508771
# H9 Es híbrido con un índice de homogeneidad 0.6486486486486487
# H10 Es híbrido con un índice de homogeneidad 0.6285714285714286
# H11 Es híbrido con un índice de homogeneidad 0.7
# H12 Es híbrido con un índice de homogeneidad 0.6285714285714286
# H13 Es híbrido con un índice de homogeneidad 0.5285714285714286
# H15 Es híbrido con un índice de homogeneidad 0.8428571428571429
# H16 Es híbrido con un índice de homogeneidad 0.6285714285714286
# H17 Es híbrido con un índice de homogeneidad 0.5733333333333334
# H18 Es híbrido con un índice de homogeneidad 0.4533333333333333
# H19 Es híbrido con un índice de homogeneidad 0.4189189189189189
# H20 Es híbrido con un índice de homogeneidad 0.4714285714285714
# H21 Es híbrido con un índice de homogeneidad 0.44285714285714284
# H22 Es híbrido con un índice de homogeneidad 0.44285714285714284
# H23 Es híbrido con un índice de homogeneidad 0.5526315789473685
# H24 Es híbrido con un índice de homogeneidad 0.45714285714285713
# H25 Es híbrido con un índice de homogeneidad 0.34285714285714286
# H26 Es híbrido con un índice de homogeneidad 0.6571428571428571
# H27 Es híbrido con un índice de homogeneidad 0.675
# H28 Es híbrido con un índice de homogeneidad 0.5571428571428572
# H29 Es híbrido con un índice de homogeneidad 0.4
# H30 Es híbrido con un índice de homogeneidad 0.6571428571428571
# H31 Es híbrido con un índice de homogeneidad 0.6571428571428571
# H33 Es híbrido con un índice de homogeneidad 0.6714285714285714
# H34 Es híbrido con un índice de homogeneidad 0.7571428571428571
# H35 Es híbrido con un índice de homogeneidad 0.5
# H36 Es híbrido con un índice de homogeneidad 0.38571428571428573
# H37 Es híbrido con un índice de homogeneidad 0.9571428571428572
# H38 Es híbrido con un índice de homogeneidad 0.9714285714285714
# H39 Es híbrido con un índice de homogeneidad 0.7857142857142857
# H40 Es híbrido con un índice de homogeneidad 0.5428571428571428
# H41 Es híbrido con un índice de homogeneidad 0.5714285714285714
# H42 Es híbrido con un índice de homogeneidad 0.4857142857142857
# H43 Es híbrido con un índice de homogeneidad 0.42857142857142855
# H44 Es híbrido con un índice de homogeneidad 0.6428571428571429
# H46 Es híbrido con un índice de homogeneidad 0.5571428571428572
# H51 Es híbrido con un índice de homogeneidad 0.7571428571428571
# H52 Es híbrido con un índice de homogeneidad 0.5714285714285714
# H53 Es híbrido con un índice de homogeneidad 0.44285714285714284
# H54 Es híbrido con un índice de homogeneidad 0.9428571428571428
# H55 Es híbrido con un índice de homogeneidad 0.5428571428571428
# H56 Es híbrido con un índice de homogeneidad 0.7714285714285715
# H57 Es híbrido con un índice de homogeneidad 0.4
# H58 Es híbrido con un índice de homogeneidad 0.45714285714285713
# H59 Es híbrido con un índice de homogeneidad 0.4142857142857143
# H60 Es híbrido con un índice de homogeneidad 0.37142857142857144
# H61 Es híbrido con un índice de homogeneidad 0.6285714285714286
# H64 Es híbrido con un índice de homogeneidad 0.8142857142857143
# H67 Es híbrido con un índice de homogeneidad 0.8714285714285714
# Total estudiantes en JAVA 4679
# Total estudiantes en INGLES 2 4283
# Total estudiantes en COACH 2 4679
# Numero de cursos hibridos de programación: 55

# %%
for asignatura, datos in ASIGNATURAS.items():
    print ('=========')
    print (asignatura)
    suma = 0
    for franja, valor in contFranja[asignatura].items():
        suma += valor
        print (franja + ':', valor)
    print ('Total cursos CON ESTUDIANTES', suma)
    if datos['tipo'] == 1:
        print ('Índice de homogeneidad académica', sum(nivelesEscolaresMaximos)/len(nivelesEscolaresMaximos))
# Out:
# =========
# JAVA
# Jornada de la mañana (6 a.m. a 8 a.m.): 8
# Jornada de la mañana (8 a.m. a 10 a.m.): 8
# Jornada de la mañana (10 a.m. a 12 m.): 4
# Jornada de la tarde (12 m. a 2 p.m.): 3
# Jornada de la tarde (2 p.m. a 4 p.m.): 4
# Jornada de la tarde (4 p.m. a 6 p.m.): 5
# Jornada de la noche (6 p.m. a 8 p.m.): 18
# Jornada de la noche (8 p.m. a 10 p.m.): 19
# Total cursos CON ESTUDIANTES 69
# Índice de homogeneidad académica 0.6845346866971581
# =========
# INGLES 2
# Jornada de la mañana (6 a.m. a 7 a.m.): 5
# Jornada de la mañana (7 a.m. a 8 a.m.): 5
# Jornada de la mañana (9 a.m. a 10 a.m.): 5
# Jornada de la mañana (11 a.m. a 12 m.): 4
# Jornada de la tarde (12 m. a 1 p.m.): 4
# Jornada de la tarde (1 p.m. a 2 p.m.): 4
# Jornada de la tarde (2 p.m. a 3 p.m.): 3
# Jornada de la tarde (5 p.m. a 6 p.m.): 6
# Jornada de la noche (6 p.m. a 7 p.m.): 6
# Jornada de la noche (7 p.m. a 8 p.m.): 9
# Jornada de la noche (8 p.m. a 9 p.m.): 9
# Jornada de la noche (9 p.m. a 10 p.m.): 4
# Total cursos CON ESTUDIANTES 64
# =========
# COACH 2
# Jornada de la mañana (6 a.m. a 7 a.m.): 5
# Jornada de la mañana (7 a.m. a 8 a.m.): 4
# Jornada de la mañana (8 a.m. a 9 a.m.): 5
# Jornada de la mañana (9 a.m. a 10 a.m.): 2
# Jornada de la mañana (10 a.m. a 11 a.m.): 4
# Jornada de la mañana (11 a.m. a 12 m.): 2
# Jornada de la tarde (12 m. a 1 p.m.): 5
# Jornada de la tarde (1 p.m. a 2 p.m.): 5
# Jornada de la tarde (2 p.m. a 3 p.m.): 2
# Jornada de la tarde (3 p.m. a 4 p.m.): 4
# Jornada de la tarde (4 p.m. a 5 p.m.): 4
# Jornada de la tarde (5 p.m. a 6 p.m.): 5
# Jornada de la noche (6 p.m. a 7 p.m.): 7
# Jornada de la noche (7 p.m. a 8 p.m.): 5
# Jornada de la noche (8 p.m. a 9 p.m.): 6
# Jornada de la noche (9 p.m. a 10 p.m.): 9
# Total cursos CON ESTUDIANTES 74

# %%
# print ('Estudiantes procesados con cursos asignados: +', totalesInscritos)
# print ('Estudiante con discapacidad: +', totalesDiscapacitados)
# print ('Estudiantes con problemas de cruces de horarios: -', totalesIncorrectos)
# print ('Estudiantes encontrados y excluidos correctamente: +', totalesExcluidos)
# print ('Estudiantes totales procesados:', totales)

# %% [markdown]
# # GUARDADO

# %%
copiaDatos = pd.concat([DATOS_PRECARGA, DATOS_FASE2.sort_values(by=[COLUMNA_NIVEL_ESTUDIO], ignore_index = True)], ignore_index = True)
copiaDatos['PROGRAMACION'] = pd.Series(colProgF1+colProgF2)
copiaDatos['INGLES'] = pd.Series(colIngF1+colIngF2)
copiaDatos['COACH'] = pd.Series(colCoachF1+colCoachF2)

# %%
copiaDatos.columns
# Out:
# Index(['DOCUMENTO', 'CODIGO', 'NOMBRE', 'APELLIDO', 'TELEFONO_MINTIC',
#        'TELEFONO_FORMULARIO', 'TELEFONO_SISTEMA_ACADEMICO', 'EMAIL',
#        'DISP_PROGRAMACION', 'DISP_INGLES', 'DISP_COACHING',
#        'TRAB_COLABORATIVO', 'NIVEL_EDUCATIVO_AGRUPADO', 'PRECARGA',
#        'SOLICITA_CAMBIO', 'CAMBIO_EFECTUADO', 'PROGRAMACION', 'INGLES',
#        'COACH'],
#       dtype='object')

# %%
columnas = [('PROGRAMACION', 'H'), ('INGLES', 'M'), ('COACH', 'N')]
nombreBase = './OUTPUT/GRUPOS/CURSOS'
for i in range(1, NUMERO_GRUPOS + 1):
    dfs = []
    nombreArchivo = nombreBase    
    for columna, codigo in columnas:
        codigo = codigo + str(i)
        nombreArchivo += '_' + codigo
        df = copiaDatos[copiaDatos[columna] == codigo]
        df = df[
            ['DOCUMENTO', 'CODIGO', 'NOMBRE', 'APELLIDO', 'TELEFONO_SISTEMA_ACADEMICO', 'TELEFONO_MINTIC', 'TELEFONO_FORMULARIO', 'EMAIL', 'NIVEL_EDUCATIVO_AGRUPADO', columna]
        ]
        dfs.append((df, codigo))
    writer = pd.ExcelWriter(nombreArchivo + '.xlsx', engine='openpyxl')
    for df, codigo in dfs:
        df.to_excel(writer, sheet_name = codigo, index = False)    
    writer.save()

# %%
# Guardado de consolidado
from datetime import date
copiaDatos.to_excel('./OUTPUT/GRUPOS/CONSOLIDADO_MATRICULAS_' + str(date.today()) + '.xlsx', index = False)

# %%
#dfCruces = copiaDatos[copiaDatos['PROGRAMACION'] == 'CRUCE']

# %%
#dfCruces.to_excel('./OUTPUT/GRUPOS/SOLO_CRUCES_' + str(date.today()) + '.xlsx', index = False)
