# %%
import pandas as pd

# %% [markdown]
# # CONFIGURACIÓN

# %%
# 1. Comportamiento:
LIMITE_POR_GRUPO = 70
TOLERANCIA = 2
TOLERANCIA_ACTIVADA = False
NUMERO_GRUPOS = 58
CURSO_HORA_SIN_ASIGNAR = 'Sin asignar' # Si queda algún grupo sin asignarle horario
GENERACION_CURSOS_AUTOMATICA = False # Si se establece como False es necesario poner el número de grupos manualmente más abajo
JORNADAS_AUTOMATICAS = False # Si se establece como False es necesario poner la distribución por jornadas manualmente más abajo
# Estrategias existentes: BALANCEADO, LLENAR
ESTRATEGIA_DEFECTO = 'LLENAR' 

# 2. Toma de datos:
COLUMNA_DISP_PROGRAMACION = 'DISP_PROGRAMACION'
COLUMNA_DISP_INGLES = 'DISP_INGLES'
COLUMNA_DISP_COACH = 'DISP_COACHING'
COLUMNA_NIVEL_ESTUDIO = 'NIVEL_EDUCATIVO_AGRUPADO'
COLUMNA_CODIGO = 'CODIGO'

# x. Configuración de columnas de archivo de cambios de horario
COLUMNAS_CAMBIOS_HORARIO = {
    'DOCUMENTO': 'Cédula del estudiante',
    COLUMNA_CODIGO: 'Código del estudiante',
    COLUMNA_DISP_PROGRAMACION: 'Horarios disponibles de PROGRAMACIÓN',
    COLUMNA_DISP_INGLES: 'Horarios disponibles INGLÉS',
    COLUMNA_DISP_COACH: 'Horarios disponibles COACH'
}


# x. Asignaturas a tener en cuenta. 
#    Formato: nombre (llave) => código de sistema académico, tipo (1 para horario unido, 2 para granular).
ASIGNATURAS = {
    'SOFTWARE': {
        'codigo': 'O',
        'tipo': 1        
    },
    'INGLES 3': {
        'codigo': 'S',
        'tipo': 2
    },
    'COACH 3': {
        'codigo': 'T',
        'tipo': 2
    }
}

# x. Codificación de los horarios. Estos deben de coincidir en el formato con el que se alimenta el software.
#    Franjas unidas se us
FRANJAS_UNIDAS = {
    'MAÑANA': [
        'Jornada de la mañana (6 a.m. a 8 a.m.)',
        'Jornada de la mañana (8 a.m. a 10 a.m.)',
        'Jornada de la mañana (10 a.m. a 12 m.)'
    ],
    'TARDE': [        
        'Jornada de la tarde (12 m. a 2 p.m.)',
        'Jornada de la tarde (2 p.m. a 4 p.m.)',
        'Jornada de la tarde (4 p.m. a 6 p.m.)'
    ],
    'NOCHE': [
        'Jornada de la noche (6 p.m. a 8 p.m.)',
        'Jornada de la noche (8 p.m. a 10 p.m.)'
    ]
}

FRANJAS_GRANULARES = {
    'MAÑANA' : [        
        'Jornada de la mañana (6 a.m. a 7 a.m.)',
        'Jornada de la mañana (7 a.m. a 8 a.m.)',
        'Jornada de la mañana (8 a.m. a 9 a.m.)',
        'Jornada de la mañana (9 a.m. a 10 a.m.)',
        'Jornada de la mañana (10 a.m. a 11 a.m.)',
        'Jornada de la mañana (11 a.m. a 12 m.)'
    ],
    'TARDE': [
        'Jornada de la tarde (12 m. a 1 p.m.)',
        'Jornada de la tarde (1 p.m. a 2 p.m.)',
        'Jornada de la tarde (2 p.m. a 3 p.m.)',
        'Jornada de la tarde (3 p.m. a 4 p.m.)',
        'Jornada de la tarde (4 p.m. a 5 p.m.)',
        'Jornada de la tarde (5 p.m. a 6 p.m.)',
    ],
    'NOCHE': [
        'Jornada de la noche (6 p.m. a 7 p.m.)',
        'Jornada de la noche (7 p.m. a 8 p.m.)',
        'Jornada de la noche (8 p.m. a 9 p.m.)',
        'Jornada de la noche (9 p.m. a 10 p.m.)'
    ]
}

# x. Número de grupos por jornada. Debe de coincidir con el número de grupos a crear.
#    Este campo permite cambiar la distribución de los grupos en las jornadas.
JORNADAS = {
    'MAÑANA': 22,
    'TARDE': 12,
    'NOCHE': 36
}

JORNADAS_MANUALES = {
    'SOFTWARE': { #69
        'MAÑANA': 20,
        'TARDE': 12,
        'NOCHE': 37
    },
    'INGLES 3': { #64
        'MAÑANA': 19,
        'TARDE': 17,
        'NOCHE': 28
    },
    'COACH 3': { #74
        'MAÑANA': 22, #
        'TARDE': 25,
        'NOCHE': 27
    }
}

# x. Número de grupos manuales. El tipo de franja horaria debe de coincidir con el definido en ASIGNATURAS.
#    Debe existir un diccionario por asignatura que contenga cada jornada, la cual contiene una lista de tuplas.
#    Donde el primer elemento es la franja horaria y el segundo la cantidad.
#    Para estimar la cantidad de grupos se puede usar el Script Indagador. Los grupos deben de coincidir con la
#    distribución definida (ya sea que esté en automático o manual)

CURSOS_MANUALES = {
    'SOFTWARE': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 8 a.m.)', 8),
            ('Jornada de la mañana (8 a.m. a 10 a.m.)', 8),
            ('Jornada de la mañana (10 a.m. a 12 m.)', 4)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 2 p.m.)', 3),
            ('Jornada de la tarde (2 p.m. a 4 p.m.)', 4),
            ('Jornada de la tarde (4 p.m. a 6 p.m.)', 5)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 8 p.m.)', 18),
            ('Jornada de la noche (8 p.m. a 10 p.m.)', 19)
        ]
    },
    'INGLES 3': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 7 a.m.)', 5),
            ('Jornada de la mañana (7 a.m. a 8 a.m.)', 5),
            ('Jornada de la mañana (8 a.m. a 9 a.m.)', 0),
            ('Jornada de la mañana (9 a.m. a 10 a.m.)', 5),
            ('Jornada de la mañana (10 a.m. a 11 a.m.)', 0),
            ('Jornada de la mañana (11 a.m. a 12 m.)', 4)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 1 p.m.)', 4),
            ('Jornada de la tarde (1 p.m. a 2 p.m.)', 4),
            ('Jornada de la tarde (2 p.m. a 3 p.m.)', 3),
            ('Jornada de la tarde (3 p.m. a 4 p.m.)', 0),
            ('Jornada de la tarde (4 p.m. a 5 p.m.)', 0),
            ('Jornada de la tarde (5 p.m. a 6 p.m.)', 6)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 7 p.m.)', 6),
            ('Jornada de la noche (7 p.m. a 8 p.m.)', 9),
            ('Jornada de la noche (8 p.m. a 9 p.m.)', 9),
            ('Jornada de la noche (9 p.m. a 10 p.m.)', 4)
        ]
    },
    'COACH 3': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 7 a.m.)', 5),
            ('Jornada de la mañana (7 a.m. a 8 a.m.)', 4),
            ('Jornada de la mañana (8 a.m. a 9 a.m.)', 5),
            ('Jornada de la mañana (9 a.m. a 10 a.m.)', 2),
            ('Jornada de la mañana (10 a.m. a 11 a.m.)', 4),
            ('Jornada de la mañana (11 a.m. a 12 m.)', 2)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 1 p.m.)', 5),
            ('Jornada de la tarde (1 p.m. a 2 p.m.)', 5),
            ('Jornada de la tarde (2 p.m. a 3 p.m.)', 2),
            ('Jornada de la tarde (3 p.m. a 4 p.m.)', 4),
            ('Jornada de la tarde (4 p.m. a 5 p.m.)', 4),
            ('Jornada de la tarde (5 p.m. a 6 p.m.)', 5)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 7 p.m.)', 7),
            ('Jornada de la noche (7 p.m. a 8 p.m.)', 5),
            ('Jornada de la noche (8 p.m. a 9 p.m.)', 6),
            ('Jornada de la noche (9 p.m. a 10 p.m.)', 9)
        ]
    }
}

# %%
ESTUDIANTES_EXCLUIDOS = [
#     # Estudiantes que no entran a ciclo 1
#     2220111, # Fabian David
#     2220135, # Juan Diego
#     2220249, # Farid Jose
#     2220256, # Diego Alejandro
#     2220605, # Miguel Ángel
#     2220755, # Juan David
#     2220841, # Gerson David
#     2221039, # Hector Armando
#     2221575, # Iván Camilo
#     2222796, # Andrés Felipe
#     2223097, # Camilo Andrés
    
#     # Otros estudiantes debajo de esta línea
#     # Estudiantes que no desean continuar
#     2224295, # No está en el consolidado
#     2224297, # No está en el consolidado
#     2224300, # No está en el consolidado
#     2224306, # No está en el consolidado
#     2224320, # No está en el consolidado
#     2224331, # No está en el consolidado
#     2224336, # No está en el consolidado
#     2224400, # No está en el consolidado
#     2224425, # No está en el consolidado
#     2224437, # No está en el consolidado
#     2224450, # No está en el consolidado
#     2224457, # No está en el consolidado
#     2224464, # No está en el consolidado
#     2224477, # No está en el consolidado
#     2224579, # No está en el consolidado
#     2224639, # No está en el consolidado
#     2223233, 
#     2224441, # No está en el consolidado
#     2220474,
]

# %% [markdown]
# # FUNCIONES

# %%
def verificarConfiguracion():
    # Datos cruciales de configuración
    estrategias = [
        'LLENAR',
        'BALANCEADO_PURO'
    ]
    tiposAsignaturas = [1, 2]
    llavesObligatoriasAsignaturas = ['tipo', 'codigo']
    
    # Verificaciones
    if not GENERACION_CURSOS_AUTOMATICA:
        for asignatura, jornadas in CURSOS_MANUALES.items():            
            sumaTotal = 0
            for jornada, listaJornadas in jornadas.items():
                sumaJornada = 0
                for franja, cantidad in listaJornadas:
                    sumaTotal += cantidad
                    if sumaJornada + cantidad > JORNADAS_MANUALES[asignatura][jornada]:
                        raise Exception('Se superó el número de grupos permitido para la jornada', jornada, franja)
                    sumaJornada += cantidad
                if sumaTotal > NUMERO_GRUPOS:
                    print (sumaTotal + sumaJornada)
                    raise Exception('Se superó el número de grupos permitido para la asignatura', asignatura, jornada)
                if sumaJornada != JORNADAS_MANUALES[asignatura][jornada]:
                    raise Exception('Faltan', JORNADAS_MANUALES[asignatura][jornada] - sumaJornada, 'grupos en la jornada', jornada)

# %%
#verificarConfiguracion()
# INICIALIZACIÓN DE DICCIONARIOS AUXILIARES
FRANJAS_PROGRAMACION = {}
FRANJAS_INGLES_COACH = {}
TRADUCTOR_PROGRAMACION = {}
TRADUCTOR_INGLES_COACH = {}
i = 0
for jornada in FRANJAS_GRANULARES.values():
    for franja in jornada:        
        FRANJAS_INGLES_COACH[franja] = i
        TRADUCTOR_INGLES_COACH[i] = franja
        i += 1
i = 0
for jornada in FRANJAS_UNIDAS.values():
    for franja in jornada:
        tupla = (i, i+1)
        FRANJAS_PROGRAMACION[franja] = tupla
        TRADUCTOR_PROGRAMACION[tupla] = franja
        i += 2
FRANJAS_INGLES_COACH['HOMOLOGADO'] = -1
TRADUCTOR_INGLES_COACH[-1] = 'HOMOLOGADO'

# %%
# Se le pasa cada cadena de columna de jornadas, retorna una lista con los códigos de franja
def tokenizarAsignado(cadena, separador, conjunto):
    horas = cadena.split(separador)
    rta = []
    for hora in horas:
        if hora in conjunto:
            rta.append(conjunto[hora])
    return rta
def generarAsignaturasCiclo(asignaturas):
    rta = []
    for asignatura, params in asignaturas.items():
        rta.append((asignatura, params['tipo']))
    return rta
def inicializarCursos(inicio, numero, codigo, jornada, tipo):
    cursos = {}
    if tipo == 1:
        franjas = FRANJAS_UNIDAS[jornada]
    else:
        franjas = FRANJAS_GRANULARES[jornada]
    cantidadFranjas = len(franjas)
    for i in range (inicio, numero):
        nombre = codigo + str(i)
        cursos[nombre] = {}
        cursos[nombre]['cantidad'] = 0
        cursos[nombre]['escolaridad'] = {}
        cursos[nombre]['horario'] = franjas[i % cantidadFranjas] if GENERACION_CURSOS_AUTOMATICA else CURSO_HORA_SIN_ASIGNAR
    return cursos
def inicializarJornadas(asignatura, codigo, tipo):
    num = 1
    jornadas = {}
    conjunto = JORNADAS if JORNADAS_AUTOMATICAS else JORNADAS_MANUALES[asignatura]
    
    for jornada, dist in conjunto.items():
        jornadas[jornada] = inicializarCursos(num, dist + num, codigo, jornada, tipo)
        num += dist        
    return jornadas
def inicializarAsignaturas():
    grupos = {}
    for nombre, datos in ASIGNATURAS.items():
        grupos[nombre] = inicializarJornadas(nombre, datos['codigo'], datos['tipo'])
    return grupos
def asignarHorarios():
    for asignatura, jornadas in CURSOS_MANUALES.items():
        i = 1
        for jornada, lista in jornadas.items():
            prefijoCodigo = ASIGNATURAS[asignatura]['codigo']
            tipo = ASIGNATURAS[asignatura]['tipo']
            for hora, cantidad in lista:
                for j in range (i, cantidad + i):
                    codigo = prefijoCodigo + str(j)
                    GRUPOS[asignatura][jornada][codigo]['horario'] = hora
                    i += 1

# %%
def permutar(listaProgramacion, listaIngles, listaCoach):
    for horaInicio, horaFin in listaProgramacion:
        for horaIngles in listaIngles:
            if horaIngles < horaInicio or horaIngles > horaFin:
                for horaCoach in listaCoach:
                    if horaCoach != horaIngles and (horaCoach < horaInicio or horaCoach > horaFin):
                        return (horaInicio, horaFin), horaIngles, horaCoach
    return -1
def todasPermutaciones(listaProgramacion, listaIngles, listaCoach):
    rta = []
    cant = len(listaProgramacion)
    nuevaLista = listaProgramacion.copy()
    while cant > 0:
        res = permutar(nuevaLista, listaIngles, listaCoach)
        if res != -1:
            rta.append(res)
        nuevaLista.pop(0)
        cant -= 1
    return rta

def determinarHoraTextoCurso(idCurso, tipo):
    if tipo == 1:
        traductor = TRADUCTOR_PROGRAMACION
    else:
        traductor = TRADUCTOR_INGLES_COACH
    
    return traductor[idCurso]

def determinarJornada(idCurso, tipo):
    if tipo == 1:
        conjunto = FRANJAS_UNIDAS
    else:
        conjunto = FRANJAS_GRANULARES
    
    nombreCurso = determinarHoraTextoCurso(idCurso, tipo)
    for jornada in conjunto:        
        if nombreCurso in conjunto[jornada]:
            return jornada

def menorCursoPorCodigo(asignatura, jornada, idCurso, tipo):
    costoMinimo = LIMITE_POR_GRUPO * 2
    nombreCursoMinimo = -1
    ultimo = -1
    horaCursoActual = determinarHoraTextoCurso(idCurso, tipo)
    for codigo, datos in GRUPOS[asignatura][jornada].items():
        if datos['horario'] == horaCursoActual:
            ultimo = codigo
            cantidad = datos['cantidad']
            if cantidad < costoMinimo and cantidad < LIMITE_POR_GRUPO + (TOLERANCIA if TOLERANCIA_ACTIVADA else 0):
                costoMinimo = cantidad
                nombreCursoMinimo = codigo
    if nombreCursoMinimo == -1:
        raise Exception('Los cursos de la asignatura', asignatura, 'en el horario', horaCursoActual, 'están llenos.', 'Último grupo intentado:', ultimo)
    return nombreCursoMinimo, costoMinimo

# Debe de llegarle una lista de asignaturas con un mapeado a modo de tupla (nombreAsignatura, tipo) que sea de igual
# longitud que la tupla emparejamientos
def menorCostoCurso(asignaturas, emparejamientos):
    costoMinimo = 100000
    codigosMinimos = -1
    jornadasMinimas = -1
    emparejamientoMinimo = -1
    for emparejamiento in emparejamientos:
        i = 0        
        costoActual = 0
        codigos = []
        jornadas = []
        for idCurso in emparejamiento:
            if type(idCurso) != tuple and idCurso < 0:
                codigos.append('HOMOLOGADO')
                jornadas.append('HOMOLOGADO')
                i += 1
                continue
            nombreAsignatura, tipoAsignatura = asignaturas[i]
            jornada = determinarJornada(idCurso, tipoAsignatura)
            codigoCurso, costo = menorCursoPorCodigo(nombreAsignatura, jornada, idCurso, tipoAsignatura)
            costoActual += costo
            jornadas.append(jornada)
            codigos.append(codigoCurso)
            i += 1
        if costoActual < costoMinimo:
            costoMinimo = costoActual
            codigosMinimos = codigos
            jornadasMinimas = jornadas
            emparejamientoMinimo = emparejamiento
    return codigosMinimos, jornadasMinimas, emparejamientoMinimo

def buscarCursoSinLlenar(asignatura, jornada, idCurso, tipo):
    cursosValidosLlenos = []
    horaCursoActual = determinarHoraTextoCurso(idCurso, tipo)
    for codigo, datos in GRUPOS[asignatura][jornada].items():
        if datos['horario'] == horaCursoActual:            
            if datos['cantidad'] < LIMITE_POR_GRUPO:
                return codigo, horaCursoActual
            else:
                cursosValidosLlenos.append((codigo, horaCursoActual, datos['cantidad']))
    if TOLERANCIA_ACTIVADA:
        for codigo, hora, cantidad in cursosValidosLlenos:
            if cantidad < LIMITE_POR_GRUPO + TOLERANCIA:
                return codigo, hora
    # Si todos están llenos para la hora buscada, devuelve -1
    return -1, horaCursoActual         
    
def asignamientoNaive(asignaturas, emparejamientos):
    # [((12, 13), 15, 14)]
    horaCursoActual = -1
    ultimo = -1
    for emparejamiento in emparejamientos:
        # ((12, 13), 15, 14)
        i = 0
        codigos = []
        jornadas = []
        for idCurso in emparejamiento:
            # (12,13)
            if type(idCurso) != tuple and idCurso < 0:
                codigos.append('HOMOLOGADO')
                jornadas.append('HOMOLOGADO')
                i += 1
                continue
            nombreAsignatura, tipoAsignatura = asignaturas[i]
            jornada = determinarJornada(idCurso, tipoAsignatura)
            codigo, horaCursoActual = buscarCursoSinLlenar(nombreAsignatura, jornada, idCurso, tipoAsignatura)
            if codigo == -1:
                ultimo = nombreAsignatura
                break
            codigos.append(codigo)
            jornadas.append(jornada)
            i += 1
        if len(codigos) == 3:
            return codigos, jornadas, emparejamiento
    if len(emparejamientos) > 0:        
        raise Exception('Todos los cursos para el horario ', horaCursoActual, 'están llenos. Última asignatura analizada: ', ultimo)
    return -1, horaCursoActual, ultimo

# %% [markdown]
# # Lectura de datos

# %%
DATOS_PRECARGA = pd.read_excel('./INPUT/GRUPOS/CONSOLIDADO_PRECARGA_CICLO_3_DUMMY.xlsx', engine='openpyxl')
DATOS_FASE2 = pd.read_excel('./INPUT/GRUPOS/CONSOLIDADO_EST_CICLO_3_DUMMY.xlsx', engine='openpyxl')
DATOS_BALANCEO = pd.read_excel('./INPUT/GRUPOS/CONSOLIDADO_BALANCEO_CICLO_3_DUMMY.xlsx', engine='openpyxl')

# %%
# DATOS_CAMBIO = pd.read_excel('./INPUT/GRUPOS/CAMBIOS_HORARIO.xlsx', engine='openpyxl')
# DATOS_CAMBIO = DATOS_CAMBIO[COLUMNAS_CAMBIOS_HORARIO.values()]

# %%
# print('Estudiantes totales en el consolidado:', len(DATOS))
# print('Estudiantes exclucidos:', len(ESTUDIANTES_EXCLUIDOS))
# print('Total estudiantes a procesar:', len(DATOS)-len(ESTUDIANTES_EXCLUIDOS))

# %% [markdown]
# ## Demostración de permutación

# %%
# Test de permutación
# Se asume que todas las materias se ven una vez por día
# Programación 2 horas día
# Inglés 1 hora día
# Coach 1 hora día
ip = 0
programacion = tokenizarAsignado(DATOS_FASE2[COLUMNA_DISP_PROGRAMACION][ip], ';', FRANJAS_PROGRAMACION)
ingles = tokenizarAsignado(DATOS_FASE2[COLUMNA_DISP_INGLES][ip], ';', FRANJAS_INGLES_COACH)
coach = tokenizarAsignado(DATOS_FASE2[COLUMNA_DISP_COACH][ip], ';', FRANJAS_INGLES_COACH)
print (programacion)
print (ingles)
print (coach)
# Out:
# [(2, 3)]
# [0]
# [1]

# %%
permutar(programacion, ingles, coach)
# Out:
# ((2, 3), 0, 1)

# %%
todasPermutaciones(programacion, ingles, coach)
# Out:
# [((2, 3), 0, 1)]

# %% [markdown]
# # PROCESAMIENTO

# %%
def generarAsignaciones(dfDatos, infoCiclo, permitirOrganizar = False, permitirCambios = False, separarDiscapacitados = False, estrategia = ESTRATEGIA_DEFECTO):
    columnaProgramacion = []
    columnaIngles = []
    columnaCoach = []
    copiaDatos = dfDatos.copy()
    if permitirCambios:
        estudiantesConCambios = DATOS_CAMBIO[COLUMNAS_CAMBIOS_HORARIO['CODIGO']].values
    if estrategia == 'LLENAR' and permitirOrganizar:
        copiaDatos.sort_values(by=[COLUMNA_NIVEL_ESTUDIO], inplace = True, ignore_index = True)
    for index, row in copiaDatos.iterrows():
        codigoEst = row[COLUMNA_CODIGO]
        if codigoEst in ESTUDIANTES_EXCLUIDOS:
            ESTADISTICAS_PROCESADO['totalesExcluidos'] += 1
            columnaProgramacion.append('EXCLUIDO')
            columnaIngles.append('EXCLUIDO')
            columnaCoach.append('EXCLUIDO')
            continue
        if separarDiscapacitados and row['DISCAPACIDAD'] == 'Si':
            ESTADISTICAS_PROCESADO['totalesDiscapacitados'] += 1
            columnaProgramacion.append('DISCAPACITADO')
            columnaIngles.append('DISCAPACITADO')
            columnaCoach.append('DISCAPACITADO')
            continue
        if permitirCambios and codigoEst in estudiantesConCambios:
            estudianteCambiar = DATOS_CAMBIO[DATOS_CAMBIO[COLUMNAS_CAMBIOS_HORARIO['CODIGO']] == codigoEst]
            listaProgramacion = tokenizarAsignado(estudianteCambiar[COLUMNAS_CAMBIOS_HORARIO[COLUMNA_DISP_PROGRAMACION]].values[0], ';', FRANJAS_PROGRAMACION)
            listaIngles = tokenizarAsignado(estudianteCambiar[COLUMNAS_CAMBIOS_HORARIO[COLUMNA_DISP_INGLES]].values[0], ';', FRANJAS_INGLES_COACH)
            listaCoach = tokenizarAsignado(estudianteCambiar[COLUMNAS_CAMBIOS_HORARIO[COLUMNA_DISP_COACH]].values[0], ';', FRANJAS_INGLES_COACH)
        else:        
            listaProgramacion = tokenizarAsignado(row[COLUMNA_DISP_PROGRAMACION], ';', FRANJAS_PROGRAMACION)
            listaIngles = tokenizarAsignado(row[COLUMNA_DISP_INGLES], ';', FRANJAS_INGLES_COACH)
            listaCoach = tokenizarAsignado(row[COLUMNA_DISP_COACH], ';', FRANJAS_INGLES_COACH)
        permutaciones = todasPermutaciones(listaProgramacion, listaIngles, listaCoach)
        if estrategia == 'BALANCEADO':        
            cursos, jornadas, _ = menorCostoCurso(infoCiclo, permutaciones)
        elif estrategia == 'LLENAR':
            cursos, jornadas, _ = asignamientoNaive(infoCiclo, permutaciones)
        if cursos != -1:
            i = 0
            for asignatura, tipo in infoCiclo:
                if jornadas[i] != 'HOMOLOGADO':
                    GRUPOS[asignatura][jornadas[i]][cursos[i]]['cantidad'] += 1
                    nivelEstudio = row[COLUMNA_NIVEL_ESTUDIO]
                    if nivelEstudio in GRUPOS[asignatura][jornadas[i]][cursos[i]]['escolaridad']:
                        GRUPOS[asignatura][jornadas[i]][cursos[i]]['escolaridad'][nivelEstudio] += 1
                    else:
                        GRUPOS[asignatura][jornadas[i]][cursos[i]]['escolaridad'][nivelEstudio] = 1            
                i += 1
            codigoProgramacion, codigoIngles, codigoCoach = cursos
            columnaProgramacion.append(codigoProgramacion)
            columnaIngles.append(codigoIngles)
            columnaCoach.append(codigoCoach)
            ESTADISTICAS_PROCESADO['totalesInscritos'] += 1
        else:
            columnaProgramacion.append('CRUCE')
            columnaIngles.append('CRUCE')
            columnaCoach.append('CRUCE')
            ESTADISTICAS_PROCESADO['totalesIncorrectos'] += 1
        ESTADISTICAS_PROCESADO['totales'] += 1
    return columnaProgramacion, columnaIngles, columnaCoach

# %%
# Refactorización a función
INFO_CICLO = generarAsignaturasCiclo(ASIGNATURAS)
GRUPOS = inicializarAsignaturas()
if not GENERACION_CURSOS_AUTOMATICA:
    asignarHorarios()
ESTADISTICAS_PROCESADO = {
    'totales' : 0,
    'totalesInscritos' : 0,
    'totalesIncorrectos' : 0,
    'totalesExcluidos' : 0,
    'totalesDiscapacitados' : 0 
}
colProgB,colIngB, colCoachB = generarAsignaciones(DATOS_BALANCEO, INFO_CICLO, permitirOrganizar = False, permitirCambios = False, separarDiscapacitados = False, estrategia = 'BALANCEADO')
colProgF1, colIngF1, colCoachF1 = generarAsignaciones(DATOS_PRECARGA, INFO_CICLO, permitirOrganizar = False, permitirCambios = False, separarDiscapacitados = False)
colProgF2, colIngF2, colCoachF2 = generarAsignaciones(DATOS_FASE2, INFO_CICLO, permitirOrganizar = True, permitirCambios = False, separarDiscapacitados = False)

# %%
ESTADISTICAS_PROCESADO['totales']
# Out:
# 4027

# %% [markdown]
# # RESULTADOS

# %%
for asignatura, jornadas in GRUPOS.items():
    print ('========')
    print (asignatura)
    for jornada, cursos in jornadas.items():
        print ('======>', jornada)
        for curso, datos in cursos.items():
            print (curso, datos['horario'], datos['cantidad'], datos['escolaridad'])
# Out:
# ========
# SOFTWARE
# ======> MAÑANA
# O1 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'DESCONOCIDO': 2, 'BACHILLER': 36, 'PROFESIONAL+': 21, 'TÉCNICO': 11}
# O2 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 33, 'DESCONOCIDO': 1, 'TÉCNICO': 28, 'BACHILLER': 8}
# O3 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 28, 'TÉCNICO': 20, 'BACHILLER': 22}
# O4 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'BACHILLER': 49, 'PROFESIONAL+': 10, 'TÉCNICO': 11}
# O5 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 48, 'BACHILLER': 21, 'DESCONOCIDO': 1}
# O6 Jornada de la mañana (6 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 33, 'BACHILLER': 1, 'TÉCNICO': 36}
# O7 Jornada de la mañana (6 a.m. a 8 a.m.) 17 {'BACHILLER': 1, 'TÉCNICO': 16}
# O8 Jornada de la mañana (6 a.m. a 8 a.m.) 1 {'BACHILLER': 1}
# O9 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'BACHILLER': 30, 'PROFESIONAL+': 35, 'TÉCNICO': 5}
# O10 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'PROFESIONAL+': 20, 'TÉCNICO': 35, 'BACHILLER': 15}
# O11 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'PROFESIONAL+': 25, 'BACHILLER': 36, 'TÉCNICO': 9}
# O12 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'BACHILLER': 46, 'PROFESIONAL+': 14, 'TÉCNICO': 10}
# O13 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'BACHILLER': 67, 'PROFESIONAL+': 3}
# O14 Jornada de la mañana (8 a.m. a 10 a.m.) 70 {'PROFESIONAL+': 64, 'TÉCNICO': 6}
# O15 Jornada de la mañana (8 a.m. a 10 a.m.) 45 {'TÉCNICO': 45}
# O16 Jornada de la mañana (8 a.m. a 10 a.m.) 0 {}
# O17 Jornada de la mañana (10 a.m. a 12 m.) 70 {'BACHILLER': 31, 'PROFESIONAL+': 19, 'TÉCNICO': 20}
# O18 Jornada de la mañana (10 a.m. a 12 m.) 70 {'PROFESIONAL+': 28, 'BACHILLER': 30, 'TÉCNICO': 12}
# O19 Jornada de la mañana (10 a.m. a 12 m.) 70 {'DESCONOCIDO': 4, 'BACHILLER': 40, 'PROFESIONAL+': 24, 'TÉCNICO': 2}
# O20 Jornada de la mañana (10 a.m. a 12 m.) 36 {'PROFESIONAL+': 7, 'TÉCNICO': 29}
# ======> TARDE
# O21 Jornada de la tarde (12 m. a 2 p.m.) 70 {'BACHILLER': 19, 'PROFESIONAL+': 30, 'TÉCNICO': 20, 'DESCONOCIDO': 1}
# O22 Jornada de la tarde (12 m. a 2 p.m.) 70 {'BACHILLER': 23, 'TÉCNICO': 17, 'PROFESIONAL+': 30}
# O23 Jornada de la tarde (12 m. a 2 p.m.) 2 {'PROFESIONAL+': 1, 'TÉCNICO': 1}
# O24 Jornada de la tarde (2 p.m. a 4 p.m.) 70 {'BACHILLER': 30, 'TÉCNICO': 18, 'PROFESIONAL+': 22}
# O25 Jornada de la tarde (2 p.m. a 4 p.m.) 70 {'PROFESIONAL+': 27, 'DESCONOCIDO': 2, 'BACHILLER': 26, 'TÉCNICO': 15}
# O26 Jornada de la tarde (2 p.m. a 4 p.m.) 70 {'BACHILLER': 33, 'TÉCNICO': 12, 'PROFESIONAL+': 25}
# O27 Jornada de la tarde (2 p.m. a 4 p.m.) 15 {'PROFESIONAL+': 1, 'BACHILLER': 1, 'TÉCNICO': 13}
# O28 Jornada de la tarde (4 p.m. a 6 p.m.) 70 {'TÉCNICO': 12, 'PROFESIONAL+': 30, 'BACHILLER': 28}
# O29 Jornada de la tarde (4 p.m. a 6 p.m.) 70 {'TÉCNICO': 14, 'PROFESIONAL+': 33, 'BACHILLER': 23}
# O30 Jornada de la tarde (4 p.m. a 6 p.m.) 70 {'TÉCNICO': 2, 'PROFESIONAL+': 27, 'BACHILLER': 41}
# O31 Jornada de la tarde (4 p.m. a 6 p.m.) 27 {'PROFESIONAL+': 2, 'TÉCNICO': 25}
# O32 Jornada de la tarde (4 p.m. a 6 p.m.) 0 {}
# ======> NOCHE
# O33 Jornada de la noche (6 p.m. a 8 p.m.) 70 {nan: 1, 'TÉCNICO': 8, 'BACHILLER': 47, 'PROFESIONAL+': 14}
# O34 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 29, 'TÉCNICO': 4, 'BACHILLER': 37}
# O35 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 50, 'BACHILLER': 13, 'TÉCNICO': 7}
# O36 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 51, 'TÉCNICO': 17, 'BACHILLER': 2}
# O37 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 21, 'BACHILLER': 6, 'TÉCNICO': 43}
# O38 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'DESCONOCIDO': 1, 'PROFESIONAL+': 26, 'TÉCNICO': 31, 'BACHILLER': 12}
# O39 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'TÉCNICO': 7, 'PROFESIONAL+': 14, 'BACHILLER': 49}
# O40 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 63, 'BACHILLER': 6, 'TÉCNICO': 1}
# O41 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'TÉCNICO': 43, 'BACHILLER': 6, 'PROFESIONAL+': 20, 'DESCONOCIDO': 1}
# O42 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'TÉCNICO': 17, 'PROFESIONAL+': 28, 'BACHILLER': 25}
# O43 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 69, 'TÉCNICO': 1}
# O44 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'TÉCNICO': 1, 'BACHILLER': 66, 'DESCONOCIDO': 1, 'PROFESIONAL+': 2}
# O45 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'BACHILLER': 1, 'PROFESIONAL+': 69}
# O46 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 56, 'TÉCNICO': 14}
# O47 Jornada de la noche (6 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 1, 'TÉCNICO': 69}
# O48 Jornada de la noche (6 p.m. a 8 p.m.) 27 {'TÉCNICO': 27}
# O49 Jornada de la noche (6 p.m. a 8 p.m.) 1 {'PROFESIONAL+': 1}
# O50 Jornada de la noche (6 p.m. a 8 p.m.) 1 {'TÉCNICO': 1}
# O51 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 41, 'TÉCNICO': 7, 'PROFESIONAL+': 22}
# O52 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 34, 'BACHILLER': 27, 'TÉCNICO': 9}
# O53 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 58, 'BACHILLER': 5, 'TÉCNICO': 7}
# O54 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 21, 'TÉCNICO': 39, 'BACHILLER': 10}
# O55 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'DESCONOCIDO': 1, 'PROFESIONAL+': 19, 'TÉCNICO': 31, 'BACHILLER': 19}
# O56 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 28, 'TÉCNICO': 22, 'PROFESIONAL+': 20}
# O57 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 6, 'TÉCNICO': 4, 'BACHILLER': 60}
# O58 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'TÉCNICO': 3, 'PROFESIONAL+': 63, 'BACHILLER': 4}
# O59 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 5, 'TÉCNICO': 56, 'PROFESIONAL+': 9}
# O60 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 26, 'BACHILLER': 22, 'TÉCNICO': 22}
# O61 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 52, 'TÉCNICO': 9, 'PROFESIONAL+': 9}
# O62 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'TÉCNICO': 1, 'BACHILLER': 69}
# O63 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 33, 'PROFESIONAL+': 37}
# O64 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 69, 'TÉCNICO': 1}
# O65 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'TÉCNICO': 1, 'BACHILLER': 1, 'PROFESIONAL+': 68}
# O66 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 11, 'TÉCNICO': 59}
# O67 Jornada de la noche (8 p.m. a 10 p.m.) 70 {'BACHILLER': 1, 'TÉCNICO': 69}
# O68 Jornada de la noche (8 p.m. a 10 p.m.) 4 {'BACHILLER': 1, 'TÉCNICO': 3}
# O69 Jornada de la noche (8 p.m. a 10 p.m.) 1 {'TÉCNICO': 1}
# ========
# INGLES 3
# ======> MAÑANA
# S1 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'PROFESIONAL+': 37, 'BACHILLER': 14, 'TÉCNICO': 19}
# S2 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'BACHILLER': 14, 'PROFESIONAL+': 37, 'TÉCNICO': 19}
# S3 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'TÉCNICO': 12, 'BACHILLER': 47, 'PROFESIONAL+': 11}
# S4 Jornada de la mañana (6 a.m. a 7 a.m.) 67 {'PROFESIONAL+': 31, 'BACHILLER': 4, 'TÉCNICO': 32}
# S5 Jornada de la mañana (6 a.m. a 7 a.m.) 1 {'TÉCNICO': 1}
# S6 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 30, 'BACHILLER': 22, 'TÉCNICO': 18}
# S7 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'BACHILLER': 21, 'TÉCNICO': 18, 'PROFESIONAL+': 31}
# S8 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'TÉCNICO': 1, 'BACHILLER': 41, 'PROFESIONAL+': 28}
# S9 Jornada de la mañana (7 a.m. a 8 a.m.) 49 {'BACHILLER': 1, 'PROFESIONAL+': 15, 'TÉCNICO': 33}
# S10 Jornada de la mañana (7 a.m. a 8 a.m.) 1 {'BACHILLER': 1}
# S11 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'BACHILLER': 36, 'PROFESIONAL+': 22, 'TÉCNICO': 12}
# S12 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'BACHILLER': 28, 'TÉCNICO': 19, 'PROFESIONAL+': 23}
# S13 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'BACHILLER': 48, 'TÉCNICO': 2, 'PROFESIONAL+': 18, 'DESCONOCIDO': 2}
# S14 Jornada de la mañana (9 a.m. a 10 a.m.) 58 {'PROFESIONAL+': 22, 'TÉCNICO': 36}
# S15 Jornada de la mañana (9 a.m. a 10 a.m.) 0 {}
# S16 Jornada de la mañana (11 a.m. a 12 m.) 70 {'DESCONOCIDO': 3, 'BACHILLER': 26, 'PROFESIONAL+': 30, 'TÉCNICO': 11}
# S17 Jornada de la mañana (11 a.m. a 12 m.) 70 {'BACHILLER': 31, 'TÉCNICO': 20, 'PROFESIONAL+': 19}
# S18 Jornada de la mañana (11 a.m. a 12 m.) 70 {'BACHILLER': 39, 'PROFESIONAL+': 30, 'TÉCNICO': 1}
# S19 Jornada de la mañana (11 a.m. a 12 m.) 24 {'DESCONOCIDO': 1, 'TÉCNICO': 23}
# ======> TARDE
# S20 Jornada de la tarde (12 m. a 1 p.m.) 70 {'PROFESIONAL+': 33, 'BACHILLER': 20, 'TÉCNICO': 17}
# S21 Jornada de la tarde (12 m. a 1 p.m.) 70 {'PROFESIONAL+': 22, 'TÉCNICO': 18, 'BACHILLER': 30}
# S22 Jornada de la tarde (12 m. a 1 p.m.) 70 {'TÉCNICO': 9, 'BACHILLER': 21, 'DESCONOCIDO': 1, 'PROFESIONAL+': 39}
# S23 Jornada de la tarde (12 m. a 1 p.m.) 24 {'TÉCNICO': 24}
# S24 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'PROFESIONAL+': 24, 'DESCONOCIDO': 1, 'BACHILLER': 28, 'TÉCNICO': 17}
# S25 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'BACHILLER': 18, 'TÉCNICO': 20, 'PROFESIONAL+': 32}
# S26 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'PROFESIONAL+': 37, 'BACHILLER': 31, 'TÉCNICO': 2}
# S27 Jornada de la tarde (1 p.m. a 2 p.m.) 22 {'TÉCNICO': 21, 'BACHILLER': 1}
# S28 Jornada de la tarde (2 p.m. a 3 p.m.) 70 {'PROFESIONAL+': 31, 'BACHILLER': 23, 'TÉCNICO': 16}
# S29 Jornada de la tarde (2 p.m. a 3 p.m.) 70 {'PROFESIONAL+': 21, 'TÉCNICO': 17, 'BACHILLER': 32}
# S30 Jornada de la tarde (2 p.m. a 3 p.m.) 11 {'PROFESIONAL+': 2, 'TÉCNICO': 9}
# S31 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'DESCONOCIDO': 1, 'TÉCNICO': 17, 'BACHILLER': 33, 'PROFESIONAL+': 19}
# S32 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'PROFESIONAL+': 29, 'BACHILLER': 19, 'TÉCNICO': 22}
# S33 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'BACHILLER': 31, 'PROFESIONAL+': 23, 'TÉCNICO': 15, 'DESCONOCIDO': 1}
# S34 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'BACHILLER': 45, 'TÉCNICO': 1, 'PROFESIONAL+': 24}
# S35 Jornada de la tarde (5 p.m. a 6 p.m.) 40 {'PROFESIONAL+': 9, 'BACHILLER': 1, 'TÉCNICO': 30}
# S36 Jornada de la tarde (5 p.m. a 6 p.m.) 2 {'PROFESIONAL+': 1, 'BACHILLER': 1}
# ======> NOCHE
# S37 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'PROFESIONAL+': 31, 'BACHILLER': 26, 'TÉCNICO': 13}
# S38 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'PROFESIONAL+': 28, 'TÉCNICO': 21, 'BACHILLER': 21}
# S39 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'PROFESIONAL+': 20, 'TÉCNICO': 21, 'BACHILLER': 29}
# S40 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 25, 'DESCONOCIDO': 1, 'PROFESIONAL+': 39, 'TÉCNICO': 5}
# S41 Jornada de la noche (6 p.m. a 7 p.m.) 30 {'BACHILLER': 1, 'TÉCNICO': 29}
# S42 Jornada de la noche (6 p.m. a 7 p.m.) 1 {'TÉCNICO': 1}
# S43 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 35, 'PROFESIONAL+': 22, 'TÉCNICO': 13}
# S44 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 39, 'TÉCNICO': 21, 'BACHILLER': 10}
# S45 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'TÉCNICO': 19, 'BACHILLER': 37, 'PROFESIONAL+': 14}
# S46 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 23, 'PROFESIONAL+': 24, 'TÉCNICO': 23}
# S47 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 39, 'TÉCNICO': 16, 'PROFESIONAL+': 15}
# S48 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 16, 'BACHILLER': 53, 'DESCONOCIDO': 1}
# S49 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'TÉCNICO': 1, 'PROFESIONAL+': 69}
# S50 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 1, 'PROFESIONAL+': 27, 'TÉCNICO': 42}
# S51 Jornada de la noche (7 p.m. a 8 p.m.) 34 {'PROFESIONAL+': 1, 'TÉCNICO': 33}
# S52 Jornada de la noche (8 p.m. a 9 p.m.) 70 {nan: 1, 'TÉCNICO': 11, 'BACHILLER': 37, 'PROFESIONAL+': 21}
# S53 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 45, 'BACHILLER': 21, 'TÉCNICO': 4}
# S54 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'TÉCNICO': 45, 'BACHILLER': 8, 'PROFESIONAL+': 17}
# S55 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 26, 'TÉCNICO': 13, 'BACHILLER': 31}
# S56 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'TÉCNICO': 34, 'PROFESIONAL+': 24, 'BACHILLER': 12}
# S57 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'TÉCNICO': 4, 'PROFESIONAL+': 7, 'BACHILLER': 59}
# S58 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 64, 'BACHILLER': 6}
# S59 Jornada de la noche (8 p.m. a 9 p.m.) 63 {'TÉCNICO': 59, 'PROFESIONAL+': 4}
# S60 Jornada de la noche (8 p.m. a 9 p.m.) 1 {'TÉCNICO': 1}
# S61 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 18, 'PROFESIONAL+': 28, 'BACHILLER': 24}
# S62 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'BACHILLER': 37, 'TÉCNICO': 12, 'PROFESIONAL+': 21}
# S63 Jornada de la noche (9 p.m. a 10 p.m.) 33 {'DESCONOCIDO': 1, 'PROFESIONAL+': 16, 'TÉCNICO': 16}
# S64 Jornada de la noche (9 p.m. a 10 p.m.) 1 {'BACHILLER': 1}
# ========
# COACH 3
# ======> MAÑANA
# T1 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'PROFESIONAL+': 28, 'TÉCNICO': 20, 'BACHILLER': 22}
# T2 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'BACHILLER': 17, 'TÉCNICO': 18, 'PROFESIONAL+': 35}
# T3 Jornada de la mañana (6 a.m. a 7 a.m.) 70 {'PROFESIONAL+': 24, 'BACHILLER': 45, 'DESCONOCIDO': 1}
# T4 Jornada de la mañana (6 a.m. a 7 a.m.) 38 {'TÉCNICO': 21, 'PROFESIONAL+': 17}
# T5 Jornada de la mañana (6 a.m. a 7 a.m.) 2 {'BACHILLER': 1, 'TÉCNICO': 1}
# T6 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'BACHILLER': 16, 'PROFESIONAL+': 35, 'TÉCNICO': 19}
# T7 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'TÉCNICO': 23, 'BACHILLER': 20, 'PROFESIONAL+': 27}
# T8 Jornada de la mañana (7 a.m. a 8 a.m.) 70 {'PROFESIONAL+': 25, 'BACHILLER': 43, 'TÉCNICO': 2}
# T9 Jornada de la mañana (7 a.m. a 8 a.m.) 34 {'PROFESIONAL+': 14, 'TÉCNICO': 20}
# T10 Jornada de la mañana (8 a.m. a 9 a.m.) 70 {'TÉCNICO': 20, 'BACHILLER': 25, 'PROFESIONAL+': 24, 'DESCONOCIDO': 1}
# T11 Jornada de la mañana (8 a.m. a 9 a.m.) 70 {'BACHILLER': 31, 'TÉCNICO': 15, 'PROFESIONAL+': 24}
# T12 Jornada de la mañana (8 a.m. a 9 a.m.) 70 {'BACHILLER': 42, 'PROFESIONAL+': 18, 'TÉCNICO': 10}
# T13 Jornada de la mañana (8 a.m. a 9 a.m.) 35 {'BACHILLER': 1, 'PROFESIONAL+': 11, 'TÉCNICO': 23}
# T14 Jornada de la mañana (8 a.m. a 9 a.m.) 1 {'TÉCNICO': 1}
# T15 Jornada de la mañana (9 a.m. a 10 a.m.) 70 {'DESCONOCIDO': 2, 'TÉCNICO': 13, 'BACHILLER': 19, 'PROFESIONAL+': 36}
# T16 Jornada de la mañana (9 a.m. a 10 a.m.) 14 {'DESCONOCIDO': 3, 'PROFESIONAL+': 3, 'TÉCNICO': 8}
# T17 Jornada de la mañana (10 a.m. a 11 a.m.) 70 {'BACHILLER': 26, 'PROFESIONAL+': 32, 'TÉCNICO': 12}
# T18 Jornada de la mañana (10 a.m. a 11 a.m.) 70 {'BACHILLER': 54, 'PROFESIONAL+': 11, 'TÉCNICO': 5}
# T19 Jornada de la mañana (10 a.m. a 11 a.m.) 61 {'BACHILLER': 1, 'PROFESIONAL+': 33, 'TÉCNICO': 27}
# T20 Jornada de la mañana (10 a.m. a 11 a.m.) 1 {'TÉCNICO': 1}
# T21 Jornada de la mañana (11 a.m. a 12 m.) 70 {'TÉCNICO': 13, 'BACHILLER': 34, 'PROFESIONAL+': 22, 'DESCONOCIDO': 1}
# T22 Jornada de la mañana (11 a.m. a 12 m.) 19 {'PROFESIONAL+': 6, 'TÉCNICO': 13}
# ======> TARDE
# T23 Jornada de la tarde (12 m. a 1 p.m.) 70 {'BACHILLER': 18, 'PROFESIONAL+': 34, 'TÉCNICO': 18}
# T24 Jornada de la tarde (12 m. a 1 p.m.) 70 {'PROFESIONAL+': 33, 'TÉCNICO': 21, 'BACHILLER': 16}
# T25 Jornada de la tarde (12 m. a 1 p.m.) 70 {'BACHILLER': 48, 'PROFESIONAL+': 15, 'TÉCNICO': 7}
# T26 Jornada de la tarde (12 m. a 1 p.m.) 70 {'PROFESIONAL+': 46, 'TÉCNICO': 24}
# T27 Jornada de la tarde (12 m. a 1 p.m.) 5 {'PROFESIONAL+': 1, 'TÉCNICO': 4}
# T28 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'PROFESIONAL+': 29, 'TÉCNICO': 21, 'BACHILLER': 20}
# T29 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'PROFESIONAL+': 32, 'TÉCNICO': 20, 'BACHILLER': 18}
# T30 Jornada de la tarde (1 p.m. a 2 p.m.) 70 {'PROFESIONAL+': 17, 'BACHILLER': 39, 'TÉCNICO': 14}
# T31 Jornada de la tarde (1 p.m. a 2 p.m.) 53 {'TÉCNICO': 25, 'BACHILLER': 1, 'PROFESIONAL+': 27}
# T32 Jornada de la tarde (1 p.m. a 2 p.m.) 2 {'PROFESIONAL+': 1, 'BACHILLER': 1}
# T33 Jornada de la tarde (2 p.m. a 3 p.m.) 70 {'BACHILLER': 25, 'PROFESIONAL+': 26, 'TÉCNICO': 19}
# T34 Jornada de la tarde (2 p.m. a 3 p.m.) 55 {'BACHILLER': 21, 'DESCONOCIDO': 1, 'PROFESIONAL+': 15, 'TÉCNICO': 18}
# T35 Jornada de la tarde (3 p.m. a 4 p.m.) 70 {'PROFESIONAL+': 20, 'TÉCNICO': 13, 'BACHILLER': 37}
# T36 Jornada de la tarde (3 p.m. a 4 p.m.) 70 {'BACHILLER': 40, 'TÉCNICO': 16, 'PROFESIONAL+': 14}
# T37 Jornada de la tarde (3 p.m. a 4 p.m.) 57 {'BACHILLER': 19, 'PROFESIONAL+': 18, 'TÉCNICO': 20}
# T38 Jornada de la tarde (3 p.m. a 4 p.m.) 2 {'BACHILLER': 2}
# T39 Jornada de la tarde (4 p.m. a 5 p.m.) 70 {'PROFESIONAL+': 28, 'TÉCNICO': 13, 'BACHILLER': 29}
# T40 Jornada de la tarde (4 p.m. a 5 p.m.) 70 {'DESCONOCIDO': 2, 'PROFESIONAL+': 24, 'TÉCNICO': 14, 'BACHILLER': 30}
# T41 Jornada de la tarde (4 p.m. a 5 p.m.) 70 {'PROFESIONAL+': 26, 'TÉCNICO': 9, 'BACHILLER': 34, 'DESCONOCIDO': 1}
# T42 Jornada de la tarde (4 p.m. a 5 p.m.) 14 {'PROFESIONAL+': 2, 'TÉCNICO': 12}
# T43 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'BACHILLER': 23, 'PROFESIONAL+': 37, 'TÉCNICO': 9, 'DESCONOCIDO': 1}
# T44 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'TÉCNICO': 18, 'PROFESIONAL+': 30, 'BACHILLER': 22}
# T45 Jornada de la tarde (5 p.m. a 6 p.m.) 70 {'TÉCNICO': 10, 'BACHILLER': 34, 'PROFESIONAL+': 26}
# T46 Jornada de la tarde (5 p.m. a 6 p.m.) 60 {'PROFESIONAL+': 19, 'TÉCNICO': 41}
# T47 Jornada de la tarde (5 p.m. a 6 p.m.) 0 {}
# ======> NOCHE
# T48 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 40, 'TÉCNICO': 13, 'PROFESIONAL+': 17}
# T49 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'DESCONOCIDO': 1, 'BACHILLER': 20, 'PROFESIONAL+': 33, 'TÉCNICO': 16}
# T50 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 37, 'PROFESIONAL+': 22, 'TÉCNICO': 11}
# T51 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 32, 'TÉCNICO': 26, 'PROFESIONAL+': 12}
# T52 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'PROFESIONAL+': 26, 'BACHILLER': 44}
# T53 Jornada de la noche (6 p.m. a 7 p.m.) 70 {'BACHILLER': 1, 'PROFESIONAL+': 55, 'TÉCNICO': 14}
# T54 Jornada de la noche (6 p.m. a 7 p.m.) 42 {'PROFESIONAL+': 1, 'TÉCNICO': 41}
# T55 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 34, 'BACHILLER': 22, 'TÉCNICO': 14}
# T56 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'BACHILLER': 17, 'PROFESIONAL+': 32, 'TÉCNICO': 21}
# T57 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'TÉCNICO': 16, 'PROFESIONAL+': 15, 'BACHILLER': 39}
# T58 Jornada de la noche (7 p.m. a 8 p.m.) 70 {'PROFESIONAL+': 55, 'BACHILLER': 6, 'TÉCNICO': 9}
# T59 Jornada de la noche (7 p.m. a 8 p.m.) 24 {'TÉCNICO': 24}
# T60 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'BACHILLER': 23, 'PROFESIONAL+': 27, 'TÉCNICO': 20}
# T61 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'PROFESIONAL+': 37, 'BACHILLER': 20, 'TÉCNICO': 13}
# T62 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'BACHILLER': 34, 'PROFESIONAL+': 23, 'TÉCNICO': 13}
# T63 Jornada de la noche (8 p.m. a 9 p.m.) 70 {'BACHILLER': 20, 'PROFESIONAL+': 33, 'TÉCNICO': 17}
# T64 Jornada de la noche (8 p.m. a 9 p.m.) 13 {'PROFESIONAL+': 1, 'TÉCNICO': 12}
# T65 Jornada de la noche (8 p.m. a 9 p.m.) 1 {'TÉCNICO': 1}
# T66 Jornada de la noche (9 p.m. a 10 p.m.) 70 {nan: 1, 'TÉCNICO': 14, 'BACHILLER': 32, 'PROFESIONAL+': 23}
# T67 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 41, 'BACHILLER': 24, 'TÉCNICO': 5}
# T68 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'PROFESIONAL+': 22, 'BACHILLER': 7, 'TÉCNICO': 41}
# T69 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 19, 'PROFESIONAL+': 35, 'BACHILLER': 16}
# T70 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 10, 'BACHILLER': 44, 'PROFESIONAL+': 16}
# T71 Jornada de la noche (9 p.m. a 10 p.m.) 70 {'TÉCNICO': 1, 'BACHILLER': 23, 'DESCONOCIDO': 1, 'PROFESIONAL+': 45}
# T72 Jornada de la noche (9 p.m. a 10 p.m.) 62 {'PROFESIONAL+': 6, 'TÉCNICO': 56}
# T73 Jornada de la noche (9 p.m. a 10 p.m.) 1 {'PROFESIONAL+': 1}
# T74 Jornada de la noche (9 p.m. a 10 p.m.) 1 {'TÉCNICO': 1}

# %%
# Conteo de grupos NO vacíos
contFranja = {}
nivelesEscolaresMaximos = []
nHibridos = 0
for asignatura, jornadas in GRUPOS.items():
    contFranja[asignatura] = {}
    contEst = 0
    for jornada, cursos in jornadas.items():        
        for curso, datos in cursos.items():
            if datos['cantidad'] > 0:
                contEst += datos['cantidad']
                if datos['horario'] in contFranja[asignatura]:
                    contFranja[asignatura][datos['horario']] += 1
                else:
                    contFranja[asignatura][datos['horario']] = 1
                if ASIGNATURAS[asignatura]['tipo'] == 1:                    
                    niveles = [cantidad for cantidad in datos['escolaridad'].values()]
                    indice = max(niveles)/datos['cantidad']
                    nivelesEscolaresMaximos.append(indice)
                    if len(datos['escolaridad']) > 1:
                        nHibridos +=1
                        print (curso, 'Es híbrido con un índice de homogeneidad', indice)
    print ('Total estudiantes en', asignatura, contEst)
print ('Numero de cursos hibridos de programación:', nHibridos)
# Out:
# O1 Es híbrido con un índice de homogeneidad 0.5142857142857142
# O2 Es híbrido con un índice de homogeneidad 0.4714285714285714
# O3 Es híbrido con un índice de homogeneidad 0.4
# O4 Es híbrido con un índice de homogeneidad 0.7
# O5 Es híbrido con un índice de homogeneidad 0.6857142857142857
# O6 Es híbrido con un índice de homogeneidad 0.5142857142857142
# O7 Es híbrido con un índice de homogeneidad 0.9411764705882353
# O9 Es híbrido con un índice de homogeneidad 0.5
# O10 Es híbrido con un índice de homogeneidad 0.5
# O11 Es híbrido con un índice de homogeneidad 0.5142857142857142
# O12 Es híbrido con un índice de homogeneidad 0.6571428571428571
# O13 Es híbrido con un índice de homogeneidad 0.9571428571428572
# O14 Es híbrido con un índice de homogeneidad 0.9142857142857143
# O17 Es híbrido con un índice de homogeneidad 0.44285714285714284
# O18 Es híbrido con un índice de homogeneidad 0.42857142857142855
# O19 Es híbrido con un índice de homogeneidad 0.5714285714285714
# O20 Es híbrido con un índice de homogeneidad 0.8055555555555556
# O21 Es híbrido con un índice de homogeneidad 0.42857142857142855
# O22 Es híbrido con un índice de homogeneidad 0.42857142857142855
# O23 Es híbrido con un índice de homogeneidad 0.5
# O24 Es híbrido con un índice de homogeneidad 0.42857142857142855
# O25 Es híbrido con un índice de homogeneidad 0.38571428571428573
# O26 Es híbrido con un índice de homogeneidad 0.4714285714285714
# O27 Es híbrido con un índice de homogeneidad 0.8666666666666667
# O28 Es híbrido con un índice de homogeneidad 0.42857142857142855
# O29 Es híbrido con un índice de homogeneidad 0.4714285714285714
# O30 Es híbrido con un índice de homogeneidad 0.5857142857142857
# O31 Es híbrido con un índice de homogeneidad 0.9259259259259259
# O33 Es híbrido con un índice de homogeneidad 0.6714285714285714
# O34 Es híbrido con un índice de homogeneidad 0.5285714285714286
# O35 Es híbrido con un índice de homogeneidad 0.7142857142857143
# O36 Es híbrido con un índice de homogeneidad 0.7285714285714285
# O37 Es híbrido con un índice de homogeneidad 0.6142857142857143
# O38 Es híbrido con un índice de homogeneidad 0.44285714285714284
# O39 Es híbrido con un índice de homogeneidad 0.7
# O40 Es híbrido con un índice de homogeneidad 0.9
# O41 Es híbrido con un índice de homogeneidad 0.6142857142857143
# O42 Es híbrido con un índice de homogeneidad 0.4
# O43 Es híbrido con un índice de homogeneidad 0.9857142857142858
# O44 Es híbrido con un índice de homogeneidad 0.9428571428571428
# O45 Es híbrido con un índice de homogeneidad 0.9857142857142858
# O46 Es híbrido con un índice de homogeneidad 0.8
# O47 Es híbrido con un índice de homogeneidad 0.9857142857142858
# O51 Es híbrido con un índice de homogeneidad 0.5857142857142857
# O52 Es híbrido con un índice de homogeneidad 0.4857142857142857
# O53 Es híbrido con un índice de homogeneidad 0.8285714285714286
# O54 Es híbrido con un índice de homogeneidad 0.5571428571428572
# O55 Es híbrido con un índice de homogeneidad 0.44285714285714284
# O56 Es híbrido con un índice de homogeneidad 0.4
# O57 Es híbrido con un índice de homogeneidad 0.8571428571428571
# O58 Es híbrido con un índice de homogeneidad 0.9
# O59 Es híbrido con un índice de homogeneidad 0.8
# O60 Es híbrido con un índice de homogeneidad 0.37142857142857144
# O61 Es híbrido con un índice de homogeneidad 0.7428571428571429
# O62 Es híbrido con un índice de homogeneidad 0.9857142857142858
# O63 Es híbrido con un índice de homogeneidad 0.5285714285714286
# O64 Es híbrido con un índice de homogeneidad 0.9857142857142858
# O65 Es híbrido con un índice de homogeneidad 0.9714285714285714
# O66 Es híbrido con un índice de homogeneidad 0.8428571428571429
# O67 Es híbrido con un índice de homogeneidad 0.9857142857142858
# O68 Es híbrido con un índice de homogeneidad 0.75
# Total estudiantes en SOFTWARE 4027
# Total estudiantes en INGLES 3 3612
# Total estudiantes en COACH 3 4027
# Numero de cursos hibridos de programación: 61

# %%
for asignatura, datos in ASIGNATURAS.items():
    print ('=========')
    print (asignatura)
    suma = 0
    for franja, valor in contFranja[asignatura].items():
        suma += valor
        print (franja + ':', valor)
    print ('Total cursos CON ESTUDIANTES', suma)
    if datos['tipo'] == 1:
        print ('Índice de homogeneidad académica', sum(nivelesEscolaresMaximos)/len(nivelesEscolaresMaximos))
# Out:
# =========
# SOFTWARE
# Jornada de la mañana (6 a.m. a 8 a.m.): 8
# Jornada de la mañana (8 a.m. a 10 a.m.): 7
# Jornada de la mañana (10 a.m. a 12 m.): 4
# Jornada de la tarde (12 m. a 2 p.m.): 3
# Jornada de la tarde (2 p.m. a 4 p.m.): 4
# Jornada de la tarde (4 p.m. a 6 p.m.): 4
# Jornada de la noche (6 p.m. a 8 p.m.): 18
# Jornada de la noche (8 p.m. a 10 p.m.): 19
# Total cursos CON ESTUDIANTES 67
# Índice de homogeneidad académica 0.6936572970813533
# =========
# INGLES 3
# Jornada de la mañana (6 a.m. a 7 a.m.): 5
# Jornada de la mañana (7 a.m. a 8 a.m.): 5
# Jornada de la mañana (9 a.m. a 10 a.m.): 4
# Jornada de la mañana (11 a.m. a 12 m.): 4
# Jornada de la tarde (12 m. a 1 p.m.): 4
# Jornada de la tarde (1 p.m. a 2 p.m.): 4
# Jornada de la tarde (2 p.m. a 3 p.m.): 3
# Jornada de la tarde (5 p.m. a 6 p.m.): 6
# Jornada de la noche (6 p.m. a 7 p.m.): 6
# Jornada de la noche (7 p.m. a 8 p.m.): 9
# Jornada de la noche (8 p.m. a 9 p.m.): 9
# Jornada de la noche (9 p.m. a 10 p.m.): 4
# Total cursos CON ESTUDIANTES 63
# =========
# COACH 3
# Jornada de la mañana (6 a.m. a 7 a.m.): 5
# Jornada de la mañana (7 a.m. a 8 a.m.): 4
# Jornada de la mañana (8 a.m. a 9 a.m.): 5
# Jornada de la mañana (9 a.m. a 10 a.m.): 2
# Jornada de la mañana (10 a.m. a 11 a.m.): 4
# Jornada de la mañana (11 a.m. a 12 m.): 2
# Jornada de la tarde (12 m. a 1 p.m.): 5
# Jornada de la tarde (1 p.m. a 2 p.m.): 5
# Jornada de la tarde (2 p.m. a 3 p.m.): 2
# Jornada de la tarde (3 p.m. a 4 p.m.): 4
# Jornada de la tarde (4 p.m. a 5 p.m.): 4
# Jornada de la tarde (5 p.m. a 6 p.m.): 4
# Jornada de la noche (6 p.m. a 7 p.m.): 7
# Jornada de la noche (7 p.m. a 8 p.m.): 5
# Jornada de la noche (8 p.m. a 9 p.m.): 6
# Jornada de la noche (9 p.m. a 10 p.m.): 9
# Total cursos CON ESTUDIANTES 73

# %%
# print ('Estudiantes procesados con cursos asignados: +', totalesInscritos)
# print ('Estudiante con discapacidad: +', totalesDiscapacitados)
# print ('Estudiantes con problemas de cruces de horarios: -', totalesIncorrectos)
# print ('Estudiantes encontrados y excluidos correctamente: +', totalesExcluidos)
# print ('Estudiantes totales procesados:', totales)

# %% [markdown]
# # GUARDADO

# %%
copiaDatos = pd.concat([__, DATOS_PRECARGA, DATOS_FASE2.sort_values(by=[COLUMNA_NIVEL_ESTUDIO], ignore_index = True)], ignore_index = True)
copiaDatos['PROGRAMACION'] = pd.Series(colProgB + colProgF1+colProgF2)
copiaDatos['INGLES'] = pd.Series(colIngB + colIngF1+colIngF2)
copiaDatos['COACH'] = pd.Series(colCoachB + colCoachF1+colCoachF2)

# %%
copiaDatos.columns
# Out:
# Index(['DOCUMENTO', 'CODIGO', 'NOMBRE', 'APELLIDO', 'TELEFONO_MINTIC',
#        'TELEFONO_FORMULARIO', 'TELEFONO_SISTEMA_ACADEMICO', 'EMAIL',
#        'DISP_PROGRAMACION', 'DISP_INGLES', 'DISP_COACHING',
#        'TRAB_COLABORATIVO', 'NIVEL_EDUCATIVO_AGRUPADO', 'PRECARGA',
#        'SOLICITA_CAMBIO', 'CAMBIO_EFECTUADO', 'PROGRAMACION', 'INGLES',
#        'COACH'],
#       dtype='object')

# %%
columnas = [('PROGRAMACION', 'H'), ('INGLES', 'M'), ('COACH', 'N')]
nombreBase = './OUTPUT/GRUPOS/CURSOS'
for i in range(1, NUMERO_GRUPOS + 1):
    dfs = []
    nombreArchivo = nombreBase    
    for columna, codigo in columnas:
        codigo = codigo + str(i)
        nombreArchivo += '_' + codigo
        df = copiaDatos[copiaDatos[columna] == codigo]
        df = df[
            ['DOCUMENTO', 'CODIGO', 'NOMBRE', 'APELLIDO', 'TELEFONO_SISTEMA_ACADEMICO', 'TELEFONO_MINTIC', 'TELEFONO_FORMULARIO', 'EMAIL', 'NIVEL_EDUCATIVO_AGRUPADO', columna]
        ]
        dfs.append((df, codigo))
    writer = pd.ExcelWriter(nombreArchivo + '.xlsx', engine='openpyxl')
    for df, codigo in dfs:
        df.to_excel(writer, sheet_name = codigo, index = False)    
    writer.save()

# %%
# Guardado de consolidado
from datetime import date
copiaDatos.to_excel('./OUTPUT/GRUPOS/CONSOLIDADO_MATRICULAS_' + str(date.today()) + '.xlsx', index = False)

# %%
#dfCruces = copiaDatos[copiaDatos['PROGRAMACION'] == 'CRUCE']

# %%
#dfCruces.to_excel('./OUTPUT/GRUPOS/SOLO_CRUCES_' + str(date.today()) + '.xlsx', index = False)
