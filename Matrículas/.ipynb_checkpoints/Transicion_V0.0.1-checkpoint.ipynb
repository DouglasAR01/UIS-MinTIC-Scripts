# %%
import pandas as pd

# %%
#DATOS_FORMULARIO = 
DATOS_MAESTRO = pd.read_excel('./INPUT/TRANSICIÓN/MAESTRO_SEGUIMIENTOS.xlsx', engine='openpyxl', skiprows=1)
BD_EST_CICLO_PREVIO = pd.read_excel('./INPUT/TRANSICIÓN/MAESTRO_SEGUIMIENTOS.xlsx', engine='openpyxl', sheet_name='Base de datos').sort_values('GRUPO')
BD_EST_CICLO_PREVIO_SIN_HOM = pd.read_excel('./INPUT/TRANSICIÓN/HorariosEstudiantes_VX_2022-05-07.xlsx', engine='openpyxl')
HOM_ING_C2 = pd.read_excel('./INPUT/TRANSICIÓN/HOM_INGLES_C2.xlsx', engine='openpyxl')['Codigo'].unique()
HORAS_CONVERSION = {
    'PROGRAMACION': {
        6: 'Jornada de la mañana (6 a.m. a 8 a.m.)',
        8: 'Jornada de la mañana (8 a.m. a 10 a.m.)',
        10: 'Jornada de la mañana (10 a.m. a 12 m.)',
        12: 'Jornada de la tarde (12 m. a 2 p.m.)',
        14: 'Jornada de la tarde (2 p.m. a 4 p.m.)',
        16: 'Jornada de la tarde (4 p.m. a 6 p.m.)',
        18: 'Jornada de la noche (6 p.m. a 8 p.m.)',
        20: 'Jornada de la noche (8 p.m. a 10 p.m.)'
    },
    'ING_COACH': {
        0: 'HOMOLOGADO',
        6: 'Jornada de la mañana (6 a.m. a 7 a.m.)',
        7: 'Jornada de la mañana (7 a.m. a 8 a.m.)',
        8: 'Jornada de la mañana (8 a.m. a 9 a.m.)',
        9: 'Jornada de la mañana (9 a.m. a 10 a.m.)',
        10: 'Jornada de la mañana (10 a.m. a 11 a.m.)',
        11: 'Jornada de la mañana (11 a.m. a 12 m.)',
        12: 'Jornada de la tarde (12 m. a 1 p.m.)',
        13: 'Jornada de la tarde (1 p.m. a 2 p.m.)',
        14: 'Jornada de la tarde (2 p.m. a 3 p.m.)',
        15: 'Jornada de la tarde (3 p.m. a 4 p.m.)',
        16: 'Jornada de la tarde (4 p.m. a 5 p.m.)',
        17: 'Jornada de la tarde (5 p.m. a 6 p.m.)',
        18: 'Jornada de la noche (6 p.m. a 7 p.m.)',
        19: 'Jornada de la noche (7 p.m. a 8 p.m.)',
        20: 'Jornada de la noche (8 p.m. a 9 p.m.)',
        21: 'Jornada de la noche (9 p.m. a 10 p.m.)'
    }
}
# Out:
# C:\Users\radou\AppData\Roaming\Python\Python39\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
FRANJAS_UNIDAS = {
    'MAÑANA': [
        'Jornada de la mañana (6 a.m. a 8 a.m.)',
        'Jornada de la mañana (8 a.m. a 10 a.m.)',
        'Jornada de la mañana (10 a.m. a 12 m.)'
    ],
    'TARDE': [        
        'Jornada de la tarde (12 m. a 2 p.m.)',
        'Jornada de la tarde (2 p.m. a 4 p.m.)',
        'Jornada de la tarde (4 p.m. a 6 p.m.)'
    ],
    'NOCHE': [
        'Jornada de la noche (6 p.m. a 8 p.m.)',
        'Jornada de la noche (8 p.m. a 10 p.m.)'
    ]
}

FRANJAS_GRANULARES = {
    'MAÑANA' : [        
        'Jornada de la mañana (6 a.m. a 7 a.m.)',
        'Jornada de la mañana (7 a.m. a 8 a.m.)',
        'Jornada de la mañana (8 a.m. a 9 a.m.)',
        'Jornada de la mañana (9 a.m. a 10 a.m.)',
        'Jornada de la mañana (10 a.m. a 11 a.m.)',
        'Jornada de la mañana (11 a.m. a 12 m.)'
    ],
    'TARDE': [
        'Jornada de la tarde (12 m. a 1 p.m.)',
        'Jornada de la tarde (1 p.m. a 2 p.m.)',
        'Jornada de la tarde (2 p.m. a 3 p.m.)',
        'Jornada de la tarde (3 p.m. a 4 p.m.)',
        'Jornada de la tarde (4 p.m. a 5 p.m.)',
        'Jornada de la tarde (5 p.m. a 6 p.m.)',
    ],
    'NOCHE': [
        'Jornada de la noche (6 p.m. a 7 p.m.)',
        'Jornada de la noche (7 p.m. a 8 p.m.)',
        'Jornada de la noche (8 p.m. a 9 p.m.)',
        'Jornada de la noche (9 p.m. a 10 p.m.)'
    ]
}
FRANJAS_PROGRAMACION = {}
FRANJAS_INGLES_COACH = {}
TRADUCTOR_PROGRAMACION = {}
TRADUCTOR_INGLES_COACH = {}
i = 0
for jornada in FRANJAS_GRANULARES.values():
    for franja in jornada:        
        FRANJAS_INGLES_COACH[franja] = i
        TRADUCTOR_INGLES_COACH[i] = franja
        i += 1
i = 0
for jornada in FRANJAS_UNIDAS.values():
    for franja in jornada:
        tupla = (i, i+1)
        FRANJAS_PROGRAMACION[franja] = tupla
        TRADUCTOR_PROGRAMACION[tupla] = franja
        i += 2
FRANJAS_INGLES_COACH['HOMOLOGADO'] = -1

# %%
def tokenizarAsignado(cadena, separador, conjunto):
    horas = cadena.split(separador)
    rta = []
    for hora in horas:
        if hora in conjunto:
            rta.append(conjunto[hora])
    return rta

def permutar(listaProgramacion, listaIngles, listaCoach):
    for horaInicio, horaFin in listaProgramacion:
        for horaIngles in listaIngles:
            if horaIngles < horaInicio or horaIngles > horaFin:
                for horaCoach in listaCoach:
                    if horaCoach != horaIngles and (horaCoach < horaInicio or horaCoach > horaFin):
                        return (horaInicio, horaFin), horaIngles, horaCoach
    return -1

def todasPermutaciones(listaProgramacion, listaIngles, listaCoach):
    rta = []
    cant = len(listaProgramacion)
    nuevaLista = listaProgramacion.copy()
    while cant > 0:
        res = permutar(nuevaLista, listaIngles, listaCoach)
        if res != -1:
            rta.append(res)
        nuevaLista.pop(0)
        cant -= 1
    return rta

def convertirHora(dicAsignatura, hora):
    rta = dicAsignatura.get(hora, -1)
    if rta == -1:
        raise Exception('Hora no encontrada', hora)
    return rta

def generarEstructura():
    return {
        'DOCUMENTO': [],
        'CODIGO': [],
        'NOMBRE': [],
        'APELLIDO': [],
        'TELEFONO_MINTIC': [],
        'TELEFONO_FORMULARIO': [],
        'TELEFONO_SISTEMA_ACADEMICO': [],
        'EMAIL': [],
        'DISP_PROGRAMACION': [],
        'DISP_INGLES': [],
        'DISP_COACHING': [],
        'TRAB_COLABORATIVO': [],
        'NIVEL_EDUCATIVO_AGRUPADO': [],
        'PRECARGA': []
    }

# %%
DATOS_MAESTRO
# Out:
#       CODIGO_MINTIC  CODIGO_UIS  DOCUMENTO_IDENTIFICACION           NOMBRES  \
# 0               NaN     2220001                 1013605766           STEVEN
# 1               NaN     2220002                 1010203197     SARA VIVIANA
# 2               NaN     2220003                 1000493253    ANDRES FELIPE
# 3               NaN     2220004                 1005340078   CARLOS JOSSEPH
# 4               NaN     2220005                   10292579     FABIO NELSON
# ...             ...         ...                        ...              ...
# 4890            NaN     2224915                 1123625165      LEONARD LEE
# 4891            NaN     2224916                 1030651533  ABRAHAM EDUARDO
# 4892            NaN     2224917                 1121376017          LUZ DEY
# 4893            NaN     2224918                 1015396131     JERSON ELIAN
# 4894            NaN     2224919                 1102880736      JAIRO DAVID
#
#                 APELLIDOS                          EMAIL TELEFONO_CELULAR  \
# 0           LIZARAZO PENA           stevenlipe@gmail.com       3006408216
# 1         CARRERO PUENTES         svcarrerop@unal.edu.co       3044733148
# 2            DIAZ BARRIOS              lv72570@gmail.com       3022163198
# 3     RODRIGUEZ HERNANDEZ        jossephrguezz@gmail.com       3227001834
# 4          SARRIA SOLARTE            SANEL1029@YAHOO.COM       3012948906
# ...                   ...                            ...              ...
# 4890     LINEROS ESCALONA            llinero89@gmail.com     3103946754.0
# 4891         IBANEZ AMAYA        eduardo.iba26@gmail.com     3115525608.0
# 4892        MEDINA CADENA             luzdeymc@gmail.com     3208702188.0
# 4893       AREVALO BLANCO  Jersonarevaloblanco@gmail.com     3192487975.0
# 4894         ROMERO PEREZ      jairo.romero572@gmail.com     3006406824.0
#
#      GRUPO_PROGRAMACION                    Tutor_de_Software  \
# 0                    A40         JUAN CARLOS MARINO MORANTES
# 1                    A60             JORGE YAIR MORENO CELIS
# 2                    A56      JUAN SEBASTIAN FERNANDO VELOZA
# 3                    A34        JORGE ALFREDO JAIMES TEHERAN
# 4                    A73      JUAN SEBASTIAN ARGUELLO LOZANO
# ...                  ...                                 ...
# 4890                 A36        JORGE ALFREDO JAIMES TEHERAN
# 4891                 A68          PEDRO FELIPE GOMEZ BONILLA
# 4892                 A71         JUAN CARLOS MARINO MORANTES
# 4893                 A49  JUAN FRANCISCO JAVIER PEREZ RIVERO
# 4894                 A50  JUAN FRANCISCO JAVIER PEREZ RIVERO
#
#                     Docente_de_Python  ...  ESTADO_DEL_SEGUIMIENTO3  \
# 0        CARLOS HUMBERTO CARRENO DIAZ  ...               En Gestión
# 1                  DANIEL RINCON LEON  ...                      NaN
# 2        CARLOS ADOLFO BELTRAN CASTRO  ...                      NaN
# 3      ROGERIO ORLANDO BELTRAN CASTRO  ...                      NaN
# 4      DARIO ALEJANDRO RIANO VELANDIA  ...                      NaN
# ...                               ...  ...                      ...
# 4890    ALVARO JAVIER HERNANDEZ RUEDA  ...                      NaN
# 4891     SERGIO NICOLAS PINILLA CANON  ...               En Gestión
# 4892  YESID OSWALDO QUINTERO MARTINEZ  ...               En Gestión
# 4893        LUIS CARLOS GAMBOA GELVEZ  ...                      NaN
# 4894       MAGDA MILENA GARCIA GAMBOA  ...      Cerrado No resuelto
#
#       PREMATRICULA_CICLO_22               HORARIO JAVA  PRIORIDAD 1  \
# 0                        NO                                     NaN
# 1                        SI                                     NaN
# 2                        SI                                     NaN
# 3                        SI                                     NaN
# 4                        SI                                     NaN
# ...                     ...                                     ...
# 4890                    NaN                                     NaN
# 4891                     SI                                     NaN
# 4892                     SI  Jornada de la noche (8 p.m. a 10 p.m.)
# 4893                    NaN                                     NaN
# 4894                     SI  Jornada de la mañana (10 a.m. a 12 m.)
#
#                   HORARIO JAVA  PRIORIDAD 2  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 4890                                    NaN
# 4891                                    NaN
# 4892                                    NaN
# 4893                                    NaN
# 4894  Jornada de la tarde (4 p.m. a 6 p.m.)
#
#                 HORARIO INGLES II PRIORIDAD 1  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 4890                                      NaN
# 4891                                      NaN
# 4892   Jornada de la mañana (6 a.m. a 7 a.m.)
# 4893                                      NaN
# 4894  Jornada de la mañana (9 a.m. a 10 a.m.)
#
#               HORARIO INGLES II PRIORIDAD 2  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 4890                                    NaN
# 4891                                    NaN
# 4892                                    NaN
# 4893                                    NaN
# 4894  Jornada de la tarde (2 p.m. a 3 p.m.)
#
#          HORARIO HAB. PERSONALES PRIORIDAD 1  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 4890                                     NaN
# 4891                                     NaN
# 4892  Jornada de la mañana (7 a.m. a 8 a.m.)
# 4893                                     NaN
# 4894   Jornada de la noche (8 p.m. a 9 p.m.)
#
#          HORARIO HAB. PERSONALES PRIORIDAD 2  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 4890                                     NaN
# 4891                                     NaN
# 4892                                     NaN
# 4893                                     NaN
# 4894  Jornada de la noche (9 p.m. a 10 p.m.)
#
#                                          OBSERVACIONES   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4890          se envia informacion a traves de correo.
# 4891                                                NaN
# 4892  Está de viaje. Refiere que los había enviado. ...
# 4893  Tripulante no contesta, no se ha podido defini...
# 4894                                                 OK
#
#      OBSERVACIONES ULTIMO JUN_3
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 4890                        NaN
# 4891                        NaN
# 4892                        NaN
# 4893                        NaN
# 4894                        NaN
#
# [4895 rows x 108 columns]

# %%
BD_EST_CICLO_PREVIO
# Out:
#       CODIGO_UIS  NUMERO_DE_DOCUMENTO  PSSW_BIBLIO          NOMBRES  \
# 2414     2222416             12187571         7571            FABIO
# 932      2220934           1031142093         2093  JESSIKA GUISELL
# 3103     2223105           1010149854         9854     PAOLA ANDREA
# 2395     2222397           1037544093         4093            MATEO
# 2365     2222367           1118558984         8984    DANIEL ISAIAS
# ...          ...                  ...          ...              ...
# 834      2220836           1019066342         6342    NERCY ALEIDIS
# 3566     2223569           1090510504          504   JULIAN ALBERTO
# 3568     2223571           1026579758         9758      YULY ANDREA
# 3574     2223577           1038809051         9051   RONALD ENRIQUE
# 2367     2222369           1073151414         1414   CARLOS EDUARDO
#
#              APELLIDOS                       EMAIL ASIGNATURA GRUPO  \
# 2414        RAMOS CRUZ     ramosfabio000@gmail.com     PYTHON    A1
# 932     RODRIGUEZ ROZO          JSI005@HOTMAIL.COM     PYTHON    A1
# 3103         ASIS POLO     paolaasispolo@gmail.com     PYTHON    A1
# 2395  PALACIO RESTREPO       mateo544093@gmail.com     PYTHON    A1
# 2365   VILLEGAS PINZON  dannielvillegasp@gmail.com     PYTHON    A1
# ...                ...                         ...        ...   ...
# 834     ZABALA PEREIRA        nercyazp@hotmail.com     PYTHON    A9
# 3566  BOTELLO VALENCIA     julian.3019@hotmail.com     PYTHON    A9
# 3568      PEREZ GUZMAN    yaperez857@misena.edu.co     PYTHON    A9
# 3574      SALINA DENIS     ronaldsalina2@gmail.com     PYTHON    A9
# 2367         TELLO LEE   carlosetellolee@gmail.com     PYTHON    A9
#
#       HORA_INICIAL HORA_INICIAL_  ...  CORREO_INSTITUCIONAL_DOCENTE_PYTHON  \
# 2414             6       6:00:00  ...       misiontic.formador8@uis.edu.co
# 932              6       6:00:00  ...       misiontic.formador8@uis.edu.co
# 3103             6       6:00:00  ...       misiontic.formador8@uis.edu.co
# 2395             6       6:00:00  ...       misiontic.formador8@uis.edu.co
# 2365             6       6:00:00  ...       misiontic.formador8@uis.edu.co
# ...            ...           ...  ...                                  ...
# 834              6       6:00:00  ...      misiontic.formador56@uis.edu.co
# 3566             6       6:00:00  ...      misiontic.formador56@uis.edu.co
# 3568             6       6:00:00  ...      misiontic.formador56@uis.edu.co
# 3574             6       6:00:00  ...      misiontic.formador56@uis.edu.co
# 2367             6       6:00:00  ...      misiontic.formador56@uis.edu.co
#
#      TELEFONO_DOCENTE_PYTHON              NOMBRE_DOCENTE_INGLES  \
# 2414              3144416477  PABLO ANDRES KENNETH BLANCO GOMEZ
# 932               3144416477                MARYLIN BLANCO RIOS
# 3103              3144416477       MARIA ALEJANDRA CELY LATORRE
# 2395              3144416477       ADRIANA TERESA ROZO CARVAJAL
# 2365              3144416477   JENNIFER TATIANA MATEUS BETANCUR
# ...                      ...                                ...
# 834               3209029318                          NO APLICA
# 3566              3209029318       LEIDY TATIANA JAIMES CADAVID
# 3568              3209029318           LEONARDO CORREDOR AMARIS
# 3574              3209029318   CESAR SNEYDEER QUIJANO SARMIENTO
# 2367              3209029318   CESAR SNEYDEER QUIJANO SARMIENTO
#
#                                   CORREO_DOCENTE_INGLES  \
# 2414                    pabloandresblanco1987@gmail.com
# 932                             marylinblaris@gmail.com
# 3103                             cely.mariale@gmail.com
# 2395                             adriana_rozo@yahoo.com
# 2365  jtmatbet@correo.uis.edu.co; tatianamateus1717@...
# ...                                                 ...
# 834                                           NO APLICA
# 3566                          leidyjaimes0711@gmail.com
# 3568                         leocoram@correo.uis.edu.co
# 3574                              nyck_jack@hotmail.com
# 2367                              nyck_jack@hotmail.com
#
#      CORREO_INSTITUCIONAL_DOCENTE_INGLES  TELEFONO_DOCENTE_INGLES  \
# 2414       misiontic.ingles29@uis.edu.co               3183778698
# 932        misiontic.ingles28@uis.edu.co               3004143543
# 3103       misiontic.ingles31@uis.edu.co               3178950508
# 2395       misiontic.ingles21@uis.edu.co               3174806884
# 2365       misiontic.ingles10@uis.edu.co               3017201464
# ...                                  ...                      ...
# 834                            NO APLICA                NO APLICA
# 3566       misiontic.ingles38@uis.edu.co               3184945785
# 3568       misiontic.ingles40@uis.edu.co               3174548460
# 3574       misiontic.ingles39@uis.edu.co               3213139912
# 2367       misiontic.ingles39@uis.edu.co               3213139912
#
#                NOMBRE_DOCENTE_COACH      CORREO_DOCENTE_COACH  \
# 2414  VIVIAN CAROLINA PEREZ ALMANZA  ps.vivianperez@gmail.com
# 932    ANA VICTORIA VARGAS PIMIENTO     axlvictoria@gmail.com
# 3103    PAOLA ANDREA SANTOS ORDONES     paola08.psi@gmail.com
# 2395   ANA VICTORIA VARGAS PIMIENTO     axlvictoria@gmail.com
# 2365  VIVIAN CAROLINA PEREZ ALMANZA  ps.vivianperez@gmail.com
# ...                             ...                       ...
# 834   VIVIAN CAROLINA PEREZ ALMANZA  ps.vivianperez@gmail.com
# 3566   ANA VICTORIA VARGAS PIMIENTO     axlvictoria@gmail.com
# 3568   ANA VICTORIA VARGAS PIMIENTO     axlvictoria@gmail.com
# 3574   ANA VICTORIA VARGAS PIMIENTO     axlvictoria@gmail.com
# 2367   ANA VICTORIA VARGAS PIMIENTO     axlvictoria@gmail.com
#
#      CORREO_INSTITUCIONAL_DOCENTE_COACH  TELEFONO_DOCENTE_COACH
# 2414        misiontic.coach6@uis.edu.co              3133929166
# 932         misiontic.coach8@uis.edu.co              3108590814
# 3103        misiontic.coach7@uis.edu.co              3166301406
# 2395        misiontic.coach8@uis.edu.co              3108590814
# 2365        misiontic.coach6@uis.edu.co              3133929166
# ...                                 ...                     ...
# 834         misiontic.coach6@uis.edu.co              3133929166
# 3566        misiontic.coach8@uis.edu.co              3108590814
# 3568        misiontic.coach8@uis.edu.co              3108590814
# 3574        misiontic.coach8@uis.edu.co              3108590814
# 2367        misiontic.coach8@uis.edu.co              3108590814
#
# [4895 rows x 53 columns]

# %%
# FASE 1
datosFase1 = generarEstructura()
codigosFormulario = DATOS_FORMULARIO['columna_codigos'].unique()
for index, row in BD_EST_CICLO_PREVIO.iterrows():
    codEst = row['CODIGO_UIS']
    homologoIngles = False
    if not(codEst in codigosFormulario): # Para mantener el orden de los grupos
        continue
    if codEst in  HOM_ING_C2:
        homologoIngles = True
    dfEst = DATOS_FORMULARIO[DATOS_FORMULARIO['columna_codigos'] == codEst]
    horaDfProg = dfEst['columna_hora_prog'].get[0]
    horaDfCoach = dfEst['columna_hora_coach'].get[0]
    horaDfIng = dfEst['columna_hora_ing'].get[0] if not homologoIngles else 'HOMOLOGADO'
    necesitaAnterior = False
    precarga = True
    
    if dfEst['columna_continuar_horario'].get[0] != 'VALOR SÍ CONTINUA': # NO Mantiene los horarios
        precarga = False
        horaTempProg = tokenizarAsignado(horaDfProg, ';', FRANJAS_PROGRAMACION)
        horaTempIng = tokenizarAsignado(horaDfIng, ';', FRANJAS_INGLES_COACH)
        horaTempCoach = tokenizarAsignado(horaDfCoach, ';', FRANJAS_INGLES_COACH)
        rtaPerm = todasPermutaciones(horaTempProg, horaTempIng, horaTempCoach)
        if len(rtaPerm) == 0:
            necesitaAnterior = True
    else:
        necesitaAnterior = True
    if necesitaAnterior:
        horaDfProg = convertirHora(HORAS_CONVERSION['PROGRAMACION'], row['HORA_INICIAL'])
        horaDfIng = convertirHora(HORAS_CONVERSION['ING_COACH'], row['HORA_INICIAL2'])
        horaDfCoach = convertirHora(HORAS_CONVERSION['ING_COACH'], row['HORA_INICIAL3'])
        if horaDfIng == 'HOMOLOGADO' and not(homologoIngles):
            horaDfIng = BD_EST_CICLO_PREVIO_SIN_HOM[BD_EST_CICLO_PREVIO_SIN_HOM['CODIGO_UIS'] == codEst]['HORA_INICIAL2'].get[0]
            horaDfIng = convertirHora(HORAS_CONVERSION['ING_COACH'], horaDfIng)
        # A estas horas NO se les permuta porque ya deberían de ser válidas. Puesto que eran las del ciclo anterior
        # Hay una muy mínima posibilidad que un homologado haya cambiado de grupo en inglés
    datosFase1['DOCUMENTO'].append(row['NUMERO_DE_DOCUMENTO'])
    datosFase1['CODIGO'].append(codEst)
    datosFase1['APELLIDO'].append(row['APELLIDOS'])
    datosFase1['NOMBRE'].append(row['NOMBRES'])
    datosFase1['TELEFONO_MINTIC'].append(row['TELEFONO_MINTIC'])
    datosFase1['TELEFONO_FORMULARIO'].append(row['TELEFONO_FORMULARIO'])
    datosFase1['TELEFONO_SISTEMA_ACADEMICO'].append(row['TELEFONO_SISTEMA_ACADEMICO'])
    datosFase1['EMAIL'].append(row['EMAIL'])
    datosFase1['DISP_PROGRAMACION'].append(horaDfProg)
    datosFase1['DISP_INGLES'].append(horaDfIng)
    datosFase1['DISP_COACHING'].append(horaDfCoach)
    datosFase1['TRAB_COLABORATIVO'].append('NO APLICA')
    datosFase1['NIVEL_EDUCATIVO_AGRUPADO'].append(row['NIVEL_EDUCATIVO'])
    datosFase1['PRECARGA'].append(precarga)
dfFase1 = pd.DataFrame(datosFase1)
dfPrecarga = dfFase1[dfFase1['PRECARGA'] == True]
dfFase1 = dfFase1[dfFase1['PRECARGA'] == False]

# %%
# FASE 2
datosFase2 = generarEstructura()
for index, row in DATOS_MAESTRO.iterrows():
    codEst = row['CODIGO_UIS']
    homologoIngles = False
    if not(codEst in datosFase1['CODIGO']): # Para mantener el orden de los grupos
        continue
    if codEst in codigosHomologadosC2:
        homologoIngles = True

# %%
def concatenarColumna(col1, col2):
    rta = ''
    if col1 != '':
        rta += col1
    if col2 != '':
        rta += ';' + col2
    return rta + ';'

# %%
copiaM = DATOS_MAESTRO.copy()
copiaM['HORARIO JAVA  PRIORIDAD 1'] = copiaM['HORARIO JAVA  PRIORIDAD 1'].fillna('')
copiaM['HORARIO JAVA  PRIORIDAD 2'] = copiaM['HORARIO JAVA  PRIORIDAD 2'].fillna('')
copiaM['HORARIO INGLES II PRIORIDAD 1'] = copiaM['HORARIO INGLES II PRIORIDAD 1'].fillna('')
copiaM['HORARIO INGLES II PRIORIDAD 2'] = copiaM['HORARIO INGLES II PRIORIDAD 2'].fillna('')
copiaM['HORARIO HAB. PERSONALES PRIORIDAD 1'] = copiaM['HORARIO HAB. PERSONALES PRIORIDAD 1'].fillna('')
copiaM['HORARIO HAB. PERSONALES PRIORIDAD 2'] = copiaM['HORARIO HAB. PERSONALES PRIORIDAD 2'].fillna('')
for index, row in copiaM[:100].iterrows():
    codEst = row['CODIGO_UIS']
    necesitaAnterior = False
    homologoIngles = False
    if codEst in HOM_ING_C2:
        homologoIngles = True
    horaDfProg = concatenarColumna(row['HORARIO JAVA  PRIORIDAD 1'], row['HORARIO JAVA  PRIORIDAD 2'])
    horaDfIng = concatenarColumna(row['HORARIO INGLES II PRIORIDAD 1'], row['HORARIO INGLES II PRIORIDAD 2']) if not homologoIngles else 'HOMOLOGADO'
    horaDfCoach = concatenarColumna(row['HORARIO HAB. PERSONALES PRIORIDAD 1'], row['HORARIO HAB. PERSONALES PRIORIDAD 2'])
    if horaDfProg != ';' and horaDfIng != ';' and horaDfCoach != ';':
        
    tokens = tokenizarAsignado(horaDfProg, ';', FRANJAS_PROGRAMACION)
    print (codEst, tokenizarAsignado(horaDfProg, ';', FRANJAS_PROGRAMACION), tokenizarAsignado(horaDfIng, ';', FRANJAS_INGLES_COACH), tokenizarAsignado(horaDfCoach, ';', FRANJAS_INGLES_COACH))
# Out:
# 2220001 [] [] []
# 2220002 [] [] []
# 2220003 [] [] []
# 2220004 [] [] []
# 2220005 [] [] []
# 2220006 [] [-1] []
# 2220007 [] [] []
# 2220008 [(14, 15)] [13] [12]
# 2220009 [] [] []
# 2220010 [] [-1] []
# 2220011 [] [] []
# 2220012 [(10, 11)] [-1] [9]
# 2220013 [] [-1] []
# 2220014 [] [] []
# 2220015 [] [] []
# 2220016 [] [] []
# 2220017 [] [] []
# 2220018 [] [-1] []
# 2220019 [] [] []
# 2220020 [] [] []
# 2220021 [] [] []
# 2220022 [] [-1] []
# 2220023 [] [] []
# 2220024 [] [-1] []
# 2220025 [] [] []
# 2220026 [] [] []
# 2220027 [] [] []
# 2220028 [] [] []
# 2220029 [] [-1] []
# 2220030 [] [] []
# 2220031 [] [] []
# 2220032 [] [] []
# 2220033 [] [-1] []
# 2220034 [] [] []
# 2220035 [] [] []
# 2220036 [] [] []
# 2220037 [] [] []
# 2220038 [] [] []
# 2220039 [] [-1] []
# 2220040 [] [] []
# 2220041 [] [] []
# 2220042 [(0, 1), (6, 7)] [6, 0] [5, 1]
# 2220043 [] [] []
# 2220044 [] [] []
# 2220045 [] [] []
# 2220046 [] [] []
# 2220047 [] [] []
# 2220048 [] [] []
# 2220049 [(12, 13)] [11] [10]
# 2220050 [] [] []
# 2220051 [] [] []
# 2220052 [(0, 1), (14, 15)] [3, 5] [12, 13]
# 2220053 [] [] []
# 2220054 [] [] []
# 2220055 [] [] []
# 2220056 [] [] []
# 2220057 [(12, 13)] [14] [15]
# 2220058 [] [] []
# 2220059 [] [] []
# 2220060 [] [] []
# 2220061 [] [-1] []
# 2220062 [] [] []
# 2220063 [] [] []
# 2220064 [] [] []
# 2220065 [(12, 13), (14, 15)] [-1] [6]
# 2220066 [] [] []
# 2220067 [] [] []
# 2220068 [] [-1] []
# 2220069 [(12, 13)] [11] [14]
# 2220070 [] [] []
# 2220071 [] [-1] []
# 2220072 [] [-1] []
# 2220073 [(14, 15)] [12] [6]
# 2220074 [] [] []
# 2220075 [] [] []
# 2220076 [] [] []
# 2220077 [] [] []
# 2220078 [] [] []
# 2220079 [] [] []
# 2220080 [] [-1] []
# 2220081 [(10, 11)] [6] [7]
# 2220082 [(12, 13)] [14] [2]
# 2220083 [] [] []
# 2220084 [] [] []
# 2220085 [] [] []
# 2220086 [] [] []
# 2220087 [] [-1] []
# 2220088 [] [-1] []
# 2220089 [(14, 15)] [0] [6]
# 2220090 [(8, 9)] [3] [1]
# 2220091 [] [-1] []
# 2220092 [] [] []
# 2220093 [] [] []
# 2220094 [] [] []
# 2220095 [] [] []
# 2220096 [] [] []
# 2220097 [] [] []
# 2220098 [] [] []
# 2220099 [] [] []
# 2220100 [(10, 11)] [-1] [13]
