# %%
import pandas as pd

# %% [markdown]
# # CONFIGURACIÓN

# %%
# 1. Comportamiento:
LIMITE_POR_GRUPO = 70
TOLERANCIA = 5
TOLERANCIA_ACTIVADA = True
NUMERO_GRUPOS = 70
CURSO_HORA_SIN_ASIGNAR = 'Sin asignar' # Si queda algún grupo sin asignarle horario
GENERACION_CURSOS_AUTOMATICA = False # Si se establece como False es necesario poner el número de grupos manualmente más abajo
JORNADAS_AUTOMATICAS = False # Si se establece como False es necesario poner la distribución por jornadas manualmente más abajo

# 2. Toma de datos:
COLUMNA_DISP_PROGRAMACION = 'DISP_PROGRAMACION'
COLUMNA_DISP_INGLES = 'DISP_INGLES'
COLUMNA_DISP_COACH = 'DISP_COACHING'


# x. Asignaturas a tener en cuenta. 
#    Formato: nombre (llave) => código de sistema académico, tipo (1 para horario unido, 2 para granular).
ASIGNATURAS = {
    'PYTHON': {
        'codigo': 'A',
        'tipo': 1        
    },
    'INGLES 1': {
        'codigo': 'M',
        'tipo': 2
    },
    'COACH 1': {
        'codigo': 'N',
        'tipo': 2
    }
}

# x. Codificación de los horarios. Estos deben de coincidir en el formato con el que se alimenta el software.
#    Franjas unidas se us
FRANJAS_UNIDAS = {
    'MAÑANA': [
        'Jornada de la mañana (6 a.m. a 8 a.m.)',
        'Jornada de la mañana (8 a.m. a 10 a.m.)',
        'Jornada de la mañana (10 a.m. a 12 m.)'
    ],
    'TARDE': [        
        'Jornada de la tarde (12 m. a 2 p.m.)',
        'Jornada de la tarde (2 p.m. a 4 p.m.)',
        'Jornada de la tarde (4 p.m. a 6 p.m.)'
    ],
    'NOCHE': [
        'Jornada de la noche (6 p.m. a 8 p.m.)',
        'Jornada de la noche (8 p.m. a 10 p.m.)'
    ]
}

FRANJAS_GRANULARES = {
    'MAÑANA' : [        
        'Jornada de la mañana (6 a.m. a 7 a.m.)',
        'Jornada de la mañana (7 a.m. a 8 a.m.)',
        'Jornada de la mañana (8 a.m. a 9 a.m.)',
        'Jornada de la mañana (9 a.m. a 10 a.m.)',
        'Jornada de la mañana (10 a.m. a 11 a.m.)',
        'Jornada de la mañana (11 a.m. a 12 m.)'
    ],
    'TARDE': [
        'Jornada de la tarde (12 m. a 1 p.m.)',
        'Jornada de la tarde (1 p.m. a 2 p.m.)',
        'Jornada de la tarde (2 p.m. a 3 p.m.)',
        'Jornada de la tarde (3 p.m. a 4 p.m.)',
        'Jornada de la tarde (4 p.m. a 5 p.m.)',
        'Jornada de la tarde (5 p.m. a 6 p.m.)',
    ],
    'NOCHE': [
        'Jornada de la noche (6 p.m. a 7 p.m.)',
        'Jornada de la noche (7 p.m. a 8 p.m.)',
        'Jornada de la noche (8 p.m. a 9 p.m.)',
        'Jornada de la noche (9 p.m. a 10 p.m.)'
    ]
}

# x. Número de grupos por jornada. Debe de coincidir con el número de grupos a crear.
#    Este campo permite cambiar la distribución de los grupos en las jornadas.
JORNADAS = {
    'MAÑANA': 22,
    'TARDE': 12,
    'NOCHE': 36
}

JORNADAS_MANUALES = {
    'PYTHON': {
        'MAÑANA': 22,
        'TARDE': 12,
        'NOCHE': 36
    },
    'INGLES 1': {
        'MAÑANA': 25,
        'TARDE': 20,
        'NOCHE': 25
    },
    'COACH 1': {
        'MAÑANA': 22,
        'TARDE': 24,
        'NOCHE': 24
    }
}

# x. Número de grupos manuales. El tipo de franja horaria debe de coincidir con el definido en ASIGNATURAS.
#    Debe existir un diccionario por asignatura que contenga cada jornada, la cual contiene una lista de tuplas.
#    Donde el primer elemento es la franja horaria y el segundo la cantidad.
#    Para estimar la cantidad de grupos se puede usar el Script Indagador. Los grupos deben de coincidir con la
#    distribución definida (ya sea que esté en automático o manual)

CURSOS_MANUALES = {
    'PYTHON': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 8 a.m.)', 10),
            ('Jornada de la mañana (8 a.m. a 10 a.m.)', 10),
            ('Jornada de la mañana (10 a.m. a 12 m.)', 2)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 2 p.m.)', 2),
            ('Jornada de la tarde (2 p.m. a 4 p.m.)', 5),
            ('Jornada de la tarde (4 p.m. a 6 p.m.)', 5)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 8 p.m.)', 16),
            ('Jornada de la noche (8 p.m. a 10 p.m.)', 20)
        ]
    },
    'INGLES 1': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 7 a.m.)', 7),
            ('Jornada de la mañana (7 a.m. a 8 a.m.)', 8),
            ('Jornada de la mañana (8 a.m. a 9 a.m.)', 0),
            ('Jornada de la mañana (9 a.m. a 10 a.m.)', 5),
            ('Jornada de la mañana (10 a.m. a 11 a.m.)', 0),
            ('Jornada de la mañana (11 a.m. a 12 m.)', 5)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 1 p.m.)', 4),
            ('Jornada de la tarde (1 p.m. a 2 p.m.)', 6),
            ('Jornada de la tarde (2 p.m. a 3 p.m.)', 3),
            ('Jornada de la tarde (3 p.m. a 4 p.m.)', 0),
            ('Jornada de la tarde (4 p.m. a 5 p.m.)', 0),
            ('Jornada de la tarde (5 p.m. a 6 p.m.)', 7)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 7 p.m.)', 5),
            ('Jornada de la noche (7 p.m. a 8 p.m.)', 7),
            ('Jornada de la noche (8 p.m. a 9 p.m.)', 7),
            ('Jornada de la noche (9 p.m. a 10 p.m.)', 6)
        ]
    },
    'COACH 1': {
        'MAÑANA': [
            ('Jornada de la mañana (6 a.m. a 7 a.m.)', 5),
            ('Jornada de la mañana (7 a.m. a 8 a.m.)', 5),
            ('Jornada de la mañana (8 a.m. a 9 a.m.)', 4),
            ('Jornada de la mañana (9 a.m. a 10 a.m.)', 2),
            ('Jornada de la mañana (10 a.m. a 11 a.m.)', 4),
            ('Jornada de la mañana (11 a.m. a 12 m.)', 2)
        ],
        'TARDE': [
            ('Jornada de la tarde (12 m. a 1 p.m.)', 4),
            ('Jornada de la tarde (1 p.m. a 2 p.m.)', 4),
            ('Jornada de la tarde (2 p.m. a 3 p.m.)', 4),
            ('Jornada de la tarde (3 p.m. a 4 p.m.)', 4),
            ('Jornada de la tarde (4 p.m. a 5 p.m.)', 4),
            ('Jornada de la tarde (5 p.m. a 6 p.m.)', 4)
        ],
        'NOCHE': [
            ('Jornada de la noche (6 p.m. a 7 p.m.)', 5),
            ('Jornada de la noche (7 p.m. a 8 p.m.)', 6),
            ('Jornada de la noche (8 p.m. a 9 p.m.)', 6),
            ('Jornada de la noche (9 p.m. a 10 p.m.)', 7)
        ]
    }
}

# %% [markdown]
# # PROCESAMIENTO

# %%
# INICIALIZACIÓN DE DICCIONARIOS AUXILIARES
FRANJAS_PROGRAMACION = {}
FRANJAS_INGLES_COACH = {}
TRADUCTOR_PROGRAMACION = {}
TRADUCTOR_INGLES_COACH = {}
i = 0
for jornada in FRANJAS_GRANULARES.values():
    for franja in jornada:        
        FRANJAS_INGLES_COACH[franja] = i
        TRADUCTOR_INGLES_COACH[i] = franja
        i += 1
i = 0
for jornada in FRANJAS_UNIDAS.values():
    for franja in jornada:
        tupla = (i, i+1)
        FRANJAS_PROGRAMACION[franja] = tupla
        TRADUCTOR_PROGRAMACION[tupla] = franja
        i += 2

# %%
# Se le pasa cada cadena de columna de jornadas, retorna una lista con los códigos de franja
def tokenizarAsignado(cadena, separador, conjunto):
    horas = cadena.split(separador)
    rta = []
    for hora in horas:
        if hora in conjunto:
            rta.append(conjunto[hora])
    return rta
def inicializarCursos(inicio, numero, codigo, jornada, tipo):
    cursos = {}
    if tipo == 1:
        franjas = FRANJAS_UNIDAS[jornada]
    else:
        franjas = FRANJAS_GRANULARES[jornada]
    cantidadFranjas = len(franjas)
    for i in range (inicio, numero):
        nombre = codigo + str(i)
        cursos[nombre] = {}
        cursos[nombre]['cantidad'] = 0
        cursos[nombre]['horario'] = franjas[i % cantidadFranjas] if GENERACION_CURSOS_AUTOMATICA else CURSO_HORA_SIN_ASIGNAR
    return cursos
def inicializarJornadas(asignatura, codigo, tipo):
    num = 1
    jornadas = {}
    conjunto = JORNADAS if JORNADAS_AUTOMATICAS else JORNADAS_MANUALES[asignatura]
    for jornada, dist in conjunto.items():
        jornadas[jornada] = inicializarCursos(num, dist + num, codigo, jornada, tipo)
        num += dist        
    return jornadas
def inicializarAsignaturas():
    grupos = {}
    for nombre, datos in ASIGNATURAS.items():
        grupos[nombre] = inicializarJornadas(nombre, datos['codigo'], datos['tipo'])
    return grupos
def asignarHorarios():
    for asignatura, jornadas in CURSOS_MANUALES.items():
        i = 1
        for jornada, lista in jornadas.items():
            prefijoCodigo = ASIGNATURAS[asignatura]['codigo']
            tipo = ASIGNATURAS[asignatura]['tipo']
            for hora, cantidad in lista:
                for j in range (i, cantidad + i):
                    codigo = prefijoCodigo + str(j)
                    GRUPOS[asignatura][jornada][codigo]['horario'] = hora
                    i += 1

# %%
datos = pd.read_excel('./INPUT/GRUPOS/CONSOLIDADO_DATOS_IMPORTANTES.xlsx', engine='openpyxl')

# %%
def permutar(listaProgramacion, listaIngles, listaCoach):
    for horaInicio, horaFin in listaProgramacion:
        for horaIngles in listaIngles:
            if horaIngles < horaInicio or horaIngles > horaFin:
                for horaCoach in listaCoach:
                    if horaCoach != horaIngles and (horaCoach < horaInicio or horaCoach > horaFin):
                        return (horaInicio, horaFin), horaIngles, horaCoach
    return -1
def todasPermutaciones(listaProgramacion, listaIngles, listaCoach):
    rta = []
    cant = len(listaProgramacion)
    nuevaLista = listaProgramacion.copy()
    while cant > 0:
        res = permutar(nuevaLista, listaIngles, listaCoach)
        if res != -1:
            rta.append(res)
        nuevaLista.pop(0)
        cant -= 1
    return rta

def determinarHoraTextoCurso(idCurso, tipo):
    if tipo == 1:
        traductor = TRADUCTOR_PROGRAMACION
    else:
        traductor = TRADUCTOR_INGLES_COACH
    
    return traductor[idCurso]

def determinarJornada(idCurso, tipo):
    if tipo == 1:
        conjunto = FRANJAS_UNIDAS
    else:
        conjunto = FRANJAS_GRANULARES
    
    nombreCurso = determinarHoraTextoCurso(idCurso, tipo)  
    for jornada in conjunto:        
        if nombreCurso in conjunto[jornada]:
            return jornada

def menorCursoPorCodigo(asignatura, jornada, idCurso, tipo):
    costoMinimo = LIMITE_POR_GRUPO * 2
    nombreCursoMinimo = -1
    ultimo = -1
    horaCursoActual = determinarHoraTextoCurso(idCurso, tipo)
    for codigo, datos in GRUPOS[asignatura][jornada].items():
        if datos['horario'] == horaCursoActual:
            ultimo = codigo
            cantidad = datos['cantidad']
            if cantidad < costoMinimo and cantidad < LIMITE_POR_GRUPO + (TOLERANCIA if TOLERANCIA_ACTIVADA else 0):
                costoMinimo = cantidad
                nombreCursoMinimo = codigo
    if nombreCursoMinimo == -1:
        raise Exception('Los cursos de la asignatura', asignatura, 'en el horario', horaCursoActual, 'están llenos.', 'Último grupo intentado:', ultimo)
    return nombreCursoMinimo, costoMinimo

# Debe de llegarle una lista de asignaturas con un mapeado a modo de tupla (nombreAsignatura, tipo) que sea de igual
# longitud que la tupla emparejamientos
def menorCostoCurso(asignaturas, emparejamientos):
    costoMinimo = 100000
    codigosMinimos = -1
    jornadasMinimas = -1
    emparejamientoMinimo = -1
    for emparejamiento in emparejamientos:
        i = 0        
        costoActual = 0
        codigos = []
        jornadas = []
        for idCurso in emparejamiento:
            nombreAsignatura, tipoAsignatura = asignaturas[i]
            jornada = determinarJornada(idCurso, tipoAsignatura)
            codigoCurso, costo = menorCursoPorCodigo(nombreAsignatura, jornada, idCurso, tipoAsignatura)
            costoActual += costo
            jornadas.append(jornada)
            codigos.append(codigoCurso)
            i += 1
        if costoActual < costoMinimo:
            costoMinimo = costoActual
            codigosMinimos = codigos
            jornadasMinimas = jornadas
            emparejamientoMinimo = emparejamiento
    return codigosMinimos, jornadasMinimas, emparejamientoMinimo

# %%
# Test de permutación
# Se asume que todas las materias se ven una vez por día
# Programación 2 horas dia
# Inglés 1 hora dia
# Coach 1 hora dia
ip = 4
programacion = tokenizarAsignado(datos[COLUMNA_DISP_PROGRAMACION][ip], ';', FRANJAS_PROGRAMACION)
ingles = tokenizarAsignado(datos[COLUMNA_DISP_INGLES][ip], ';', FRANJAS_INGLES_COACH)
coach = tokenizarAsignado(datos[COLUMNA_DISP_COACH][ip], ';', FRANJAS_INGLES_COACH)
print (programacion)
print (ingles)
print (coach)
# Out:
# [(12, 13), (14, 15)]
# [14, 15, 13]
# [12, 13, 14]

# %%
permutar(programacion, ingles, coach)
# Out:
# ((12, 13), 15, 14)

# %%
todasPermutaciones(programacion, ingles, coach)
# Out:
# [((12, 13), 15, 14), ((14, 15), 13, 12)]

# %%
FRANJAS_PROGRAMACION
# Out:
# {'Jornada de la mañana (6 a.m. a 8 a.m.)': (0, 1),
#  'Jornada de la mañana (8 a.m. a 10 a.m.)': (2, 3),
#  'Jornada de la mañana (10 a.m. a 12 m.)': (4, 5),
#  'Jornada de la tarde (12 m. a 2 p.m.)': (6, 7),
#  'Jornada de la tarde (2 p.m. a 4 p.m.)': (8, 9),
#  'Jornada de la tarde (4 p.m. a 6 p.m.)': (10, 11),
#  'Jornada de la noche (6 p.m. a 8 p.m.)': (12, 13),
#  'Jornada de la noche (8 p.m. a 10 p.m.)': (14, 15)}

# %%
FRANJAS_INGLES_COACH
# Out:
# {'Jornada de la mañana (6 a.m. a 7 a.m.)': 0,
#  'Jornada de la mañana (7 a.m. a 8 a.m.)': 1,
#  'Jornada de la mañana (8 a.m. a 9 a.m.)': 2,
#  'Jornada de la mañana (9 a.m. a 10 a.m.)': 3,
#  'Jornada de la mañana (10 a.m. a 11 a.m.)': 4,
#  'Jornada de la mañana (11 a.m. a 12 m.)': 5,
#  'Jornada de la tarde (12 m. a 1 p.m.)': 6,
#  'Jornada de la tarde (1 p.m. a 2 p.m.)': 7,
#  'Jornada de la tarde (2 p.m. a 3 p.m.)': 8,
#  'Jornada de la tarde (3 p.m. a 4 p.m.)': 9,
#  'Jornada de la tarde (4 p.m. a 5 p.m.)': 10,
#  'Jornada de la tarde (5 p.m. a 6 p.m.)': 11,
#  'Jornada de la noche (6 p.m. a 7 p.m.)': 12,
#  'Jornada de la noche (7 p.m. a 8 p.m.)': 13,
#  'Jornada de la noche (8 p.m. a 9 p.m.)': 14,
#  'Jornada de la noche (9 p.m. a 10 p.m.)': 15}

# %%
c = [
    ('PYTHON', 1),
    ('INGLES 1', 2),
    ('COACH 1', 2)
]
em = todasPermutaciones(programacion, ingles, coach)
menorCostoCurso(c, em)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13260/2957804703.py in <module>
#       5 ]
#       6 em = todasPermutaciones(programacion, ingles, coach)
# ----> 7 menorCostoCurso(c, em)
#
# ~\AppData\Local\Temp/ipykernel_13260/1161824639.py in menorCostoCurso(asignaturas, emparejamientos)
#      69             nombreAsignatura, tipoAsignatura = asignaturas[i]
#      70             jornada = determinarJornada(idCurso, tipoAsignatura)
# ---> 71             codigoCurso, costo = menorCursoPorCodigo(nombreAsignatura, jornada, idCurso, tipoAsignatura)
#      72             costoActual += costo
#      73             jornadas.append(jornada)
#
# ~\AppData\Local\Temp/ipykernel_13260/1161824639.py in menorCursoPorCodigo(asignatura, jornada, idCurso, tipo)
#      43     ultimo = -1
#      44     horaCursoActual = determinarHoraTextoCurso(idCurso, tipo)
# ---> 45     for codigo, datos in GRUPOS[asignatura][jornada].items():
#      46         if datos['horario'] == horaCursoActual:
#      47             ultimo = codigo
#
# NameError: name 'GRUPOS' is not defined

# %%
columnaNueva = []
# Inicializado de los grupos
GRUPOS = inicializarAsignaturas()
if not GENERACION_CURSOS_AUTOMATICA:
    asignarHorarios()
totales = 0
for index, row in datos.iterrows():
    listaProgramacion = tokenizarAsignado(row[COLUMNA_DISP_PROGRAMACION], ';', FRANJAS_PROGRAMACION)
    listaIngles = tokenizarAsignado(row[COLUMNA_DISP_INGLES], ';', FRANJAS_INGLES_COACH)
    listaCoach = tokenizarAsignado(row[COLUMNA_DISP_COACH], ';', FRANJAS_INGLES_COACH)
    permutaciones = todasPermutaciones(listaProgramacion, listaIngles, listaCoach)
    ciclo = [ # EL CICLO SE DEBE DETERMINAR MEDIANTE ALGÚN MECANISMO
        ('PYTHON', 1),
        ('INGLES 1', 2),
        ('COACH 1', 2)
    ]
    cursos, jornadas, _ = menorCostoCurso(ciclo, permutaciones)
    if cursos != -1:
        i = 0
        for asignatura, tipo in ciclo:            
            GRUPOS[asignatura][jornadas[i]][cursos[i]]['cantidad'] += 1
            i += 1
        columnaNueva.append(' '.join(cursos))
    totales += 1

# %%
GRUPOS
# Out:
# {'PYTHON': {'MAÑANA': {'A1': {'cantidad': 61,
#     'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A2': {'cantidad': 61, 'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A3': {'cantidad': 61, 'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A4': {'cantidad': 61, 'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A5': {'cantidad': 61, 'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A6': {'cantidad': 61, 'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A7': {'cantidad': 60, 'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A8': {'cantidad': 60, 'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A9': {'cantidad': 60, 'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A10': {'cantidad': 60,
#     'horario': 'Jornada de la mañana (6 a.m. a 8 a.m.)'},
#    'A11': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A12': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A13': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A14': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A15': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A16': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A17': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A18': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A19': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A20': {'cantidad': 61,
#     'horario': 'Jornada de la mañana (8 a.m. a 10 a.m.)'},
#    'A21': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (10 a.m. a 12 m.)'},
#    'A22': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (10 a.m. a 12 m.)'}},
#   'TARDE': {'A23': {'cantidad': 64,
#     'horario': 'Jornada de la tarde (12 m. a 2 p.m.)'},
#    'A24': {'cantidad': 63, 'horario': 'Jornada de la tarde (12 m. a 2 p.m.)'},
#    'A25': {'cantidad': 63, 'horario': 'Jornada de la tarde (2 p.m. a 4 p.m.)'},
#    'A26': {'cantidad': 63, 'horario': 'Jornada de la tarde (2 p.m. a 4 p.m.)'},
#    'A27': {'cantidad': 63, 'horario': 'Jornada de la tarde (2 p.m. a 4 p.m.)'},
#    'A28': {'cantidad': 63, 'horario': 'Jornada de la tarde (2 p.m. a 4 p.m.)'},
#    'A29': {'cantidad': 62, 'horario': 'Jornada de la tarde (2 p.m. a 4 p.m.)'},
#    'A30': {'cantidad': 64, 'horario': 'Jornada de la tarde (4 p.m. a 6 p.m.)'},
#    'A31': {'cantidad': 64, 'horario': 'Jornada de la tarde (4 p.m. a 6 p.m.)'},
#    'A32': {'cantidad': 64, 'horario': 'Jornada de la tarde (4 p.m. a 6 p.m.)'},
#    'A33': {'cantidad': 64, 'horario': 'Jornada de la tarde (4 p.m. a 6 p.m.)'},
#    'A34': {'cantidad': 63,
#     'horario': 'Jornada de la tarde (4 p.m. a 6 p.m.)'}},
#   'NOCHE': {'A35': {'cantidad': 64,
#     'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A36': {'cantidad': 64, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A37': {'cantidad': 64, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A38': {'cantidad': 64, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A39': {'cantidad': 64, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A40': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A41': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A42': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A43': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A44': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A45': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A46': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A47': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A48': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A49': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A50': {'cantidad': 63, 'horario': 'Jornada de la noche (6 p.m. a 8 p.m.)'},
#    'A51': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A52': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A53': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A54': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A55': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A56': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A57': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A58': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A59': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A60': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A61': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A62': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A63': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A64': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A65': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A66': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A67': {'cantidad': 63,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A68': {'cantidad': 62,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A69': {'cantidad': 62,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'},
#    'A70': {'cantidad': 62,
#     'horario': 'Jornada de la noche (8 p.m. a 10 p.m.)'}}},
#  'INGLES 1': {'MAÑANA': {'M1': {'cantidad': 66,
#     'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'M2': {'cantidad': 66, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'M3': {'cantidad': 66, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'M4': {'cantidad': 66, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'M5': {'cantidad': 66, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'M6': {'cantidad': 66, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'M7': {'cantidad': 65, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'M8': {'cantidad': 49, 'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'M9': {'cantidad': 49, 'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'M10': {'cantidad': 49,
#     'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'M11': {'cantidad': 48,
#     'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'M12': {'cantidad': 48,
#     'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'M13': {'cantidad': 48,
#     'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'M14': {'cantidad': 48,
#     'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'M15': {'cantidad': 48,
#     'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'M16': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (9 a.m. a 10 a.m.)'},
#    'M17': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (9 a.m. a 10 a.m.)'},
#    'M18': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (9 a.m. a 10 a.m.)'},
#    'M19': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (9 a.m. a 10 a.m.)'},
#    'M20': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (9 a.m. a 10 a.m.)'},
#    'M21': {'cantidad': 59,
#     'horario': 'Jornada de la mañana (11 a.m. a 12 m.)'},
#    'M22': {'cantidad': 59,
#     'horario': 'Jornada de la mañana (11 a.m. a 12 m.)'},
#    'M23': {'cantidad': 59,
#     'horario': 'Jornada de la mañana (11 a.m. a 12 m.)'},
#    'M24': {'cantidad': 59,
#     'horario': 'Jornada de la mañana (11 a.m. a 12 m.)'},
#    'M25': {'cantidad': 59,
#     'horario': 'Jornada de la mañana (11 a.m. a 12 m.)'}},
#   'TARDE': {'M26': {'cantidad': 70,
#     'horario': 'Jornada de la tarde (12 m. a 1 p.m.)'},
#    'M27': {'cantidad': 70, 'horario': 'Jornada de la tarde (12 m. a 1 p.m.)'},
#    'M28': {'cantidad': 70, 'horario': 'Jornada de la tarde (12 m. a 1 p.m.)'},
#    'M29': {'cantidad': 69, 'horario': 'Jornada de la tarde (12 m. a 1 p.m.)'},
#    'M30': {'cantidad': 55, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'M31': {'cantidad': 55, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'M32': {'cantidad': 55, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'M33': {'cantidad': 55, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'M34': {'cantidad': 55, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'M35': {'cantidad': 54, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'M36': {'cantidad': 67, 'horario': 'Jornada de la tarde (2 p.m. a 3 p.m.)'},
#    'M37': {'cantidad': 67, 'horario': 'Jornada de la tarde (2 p.m. a 3 p.m.)'},
#    'M38': {'cantidad': 67, 'horario': 'Jornada de la tarde (2 p.m. a 3 p.m.)'},
#    'M39': {'cantidad': 62, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'M40': {'cantidad': 62, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'M41': {'cantidad': 62, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'M42': {'cantidad': 61, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'M43': {'cantidad': 61, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'M44': {'cantidad': 61, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'M45': {'cantidad': 61,
#     'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'}},
#   'NOCHE': {'M46': {'cantidad': 73,
#     'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'M47': {'cantidad': 73, 'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'M48': {'cantidad': 72, 'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'M49': {'cantidad': 72, 'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'M50': {'cantidad': 72, 'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'M51': {'cantidad': 67, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'M52': {'cantidad': 67, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'M53': {'cantidad': 67, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'M54': {'cantidad': 67, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'M55': {'cantidad': 67, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'M56': {'cantidad': 67, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'M57': {'cantidad': 66, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'M58': {'cantidad': 75, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'M59': {'cantidad': 75, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'M60': {'cantidad': 75, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'M61': {'cantidad': 75, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'M62': {'cantidad': 74, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'M63': {'cantidad': 74, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'M64': {'cantidad': 74, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'M65': {'cantidad': 56,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'M66': {'cantidad': 56,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'M67': {'cantidad': 56,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'M68': {'cantidad': 55,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'M69': {'cantidad': 55,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'M70': {'cantidad': 55,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'}}},
#  'COACH 1': {'MAÑANA': {'N1': {'cantidad': 61,
#     'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'N2': {'cantidad': 61, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'N3': {'cantidad': 61, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'N4': {'cantidad': 61, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'N5': {'cantidad': 60, 'horario': 'Jornada de la mañana (6 a.m. a 7 a.m.)'},
#    'N6': {'cantidad': 64, 'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'N7': {'cantidad': 63, 'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'N8': {'cantidad': 63, 'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'N9': {'cantidad': 63, 'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'N10': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (7 a.m. a 8 a.m.)'},
#    'N11': {'cantidad': 67,
#     'horario': 'Jornada de la mañana (8 a.m. a 9 a.m.)'},
#    'N12': {'cantidad': 67,
#     'horario': 'Jornada de la mañana (8 a.m. a 9 a.m.)'},
#    'N13': {'cantidad': 66,
#     'horario': 'Jornada de la mañana (8 a.m. a 9 a.m.)'},
#    'N14': {'cantidad': 66,
#     'horario': 'Jornada de la mañana (8 a.m. a 9 a.m.)'},
#    'N15': {'cantidad': 43,
#     'horario': 'Jornada de la mañana (9 a.m. a 10 a.m.)'},
#    'N16': {'cantidad': 43,
#     'horario': 'Jornada de la mañana (9 a.m. a 10 a.m.)'},
#    'N17': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (10 a.m. a 11 a.m.)'},
#    'N18': {'cantidad': 63,
#     'horario': 'Jornada de la mañana (10 a.m. a 11 a.m.)'},
#    'N19': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (10 a.m. a 11 a.m.)'},
#    'N20': {'cantidad': 62,
#     'horario': 'Jornada de la mañana (10 a.m. a 11 a.m.)'},
#    'N21': {'cantidad': 52,
#     'horario': 'Jornada de la mañana (11 a.m. a 12 m.)'},
#    'N22': {'cantidad': 52,
#     'horario': 'Jornada de la mañana (11 a.m. a 12 m.)'}},
#   'TARDE': {'N23': {'cantidad': 64,
#     'horario': 'Jornada de la tarde (12 m. a 1 p.m.)'},
#    'N24': {'cantidad': 64, 'horario': 'Jornada de la tarde (12 m. a 1 p.m.)'},
#    'N25': {'cantidad': 64, 'horario': 'Jornada de la tarde (12 m. a 1 p.m.)'},
#    'N26': {'cantidad': 63, 'horario': 'Jornada de la tarde (12 m. a 1 p.m.)'},
#    'N27': {'cantidad': 72, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'N28': {'cantidad': 72, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'N29': {'cantidad': 71, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'N30': {'cantidad': 71, 'horario': 'Jornada de la tarde (1 p.m. a 2 p.m.)'},
#    'N31': {'cantidad': 41, 'horario': 'Jornada de la tarde (2 p.m. a 3 p.m.)'},
#    'N32': {'cantidad': 40, 'horario': 'Jornada de la tarde (2 p.m. a 3 p.m.)'},
#    'N33': {'cantidad': 40, 'horario': 'Jornada de la tarde (2 p.m. a 3 p.m.)'},
#    'N34': {'cantidad': 40, 'horario': 'Jornada de la tarde (2 p.m. a 3 p.m.)'},
#    'N35': {'cantidad': 61, 'horario': 'Jornada de la tarde (3 p.m. a 4 p.m.)'},
#    'N36': {'cantidad': 61, 'horario': 'Jornada de la tarde (3 p.m. a 4 p.m.)'},
#    'N37': {'cantidad': 61, 'horario': 'Jornada de la tarde (3 p.m. a 4 p.m.)'},
#    'N38': {'cantidad': 61, 'horario': 'Jornada de la tarde (3 p.m. a 4 p.m.)'},
#    'N39': {'cantidad': 66, 'horario': 'Jornada de la tarde (4 p.m. a 5 p.m.)'},
#    'N40': {'cantidad': 66, 'horario': 'Jornada de la tarde (4 p.m. a 5 p.m.)'},
#    'N41': {'cantidad': 66, 'horario': 'Jornada de la tarde (4 p.m. a 5 p.m.)'},
#    'N42': {'cantidad': 66, 'horario': 'Jornada de la tarde (4 p.m. a 5 p.m.)'},
#    'N43': {'cantidad': 65, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'N44': {'cantidad': 65, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'N45': {'cantidad': 65, 'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'},
#    'N46': {'cantidad': 64,
#     'horario': 'Jornada de la tarde (5 p.m. a 6 p.m.)'}},
#   'NOCHE': {'N47': {'cantidad': 74,
#     'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'N48': {'cantidad': 73, 'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'N49': {'cantidad': 73, 'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'N50': {'cantidad': 73, 'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'N51': {'cantidad': 73, 'horario': 'Jornada de la noche (6 p.m. a 7 p.m.)'},
#    'N52': {'cantidad': 60, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'N53': {'cantidad': 59, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'N54': {'cantidad': 59, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'N55': {'cantidad': 59, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'N56': {'cantidad': 59, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'N57': {'cantidad': 59, 'horario': 'Jornada de la noche (7 p.m. a 8 p.m.)'},
#    'N58': {'cantidad': 66, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'N59': {'cantidad': 66, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'N60': {'cantidad': 66, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'N61': {'cantidad': 66, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'N62': {'cantidad': 65, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'N63': {'cantidad': 65, 'horario': 'Jornada de la noche (8 p.m. a 9 p.m.)'},
#    'N64': {'cantidad': 68,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'N65': {'cantidad': 68,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'N66': {'cantidad': 67,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'N67': {'cantidad': 67,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'N68': {'cantidad': 67,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'N69': {'cantidad': 67,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'},
#    'N70': {'cantidad': 67,
#     'horario': 'Jornada de la noche (9 p.m. a 10 p.m.)'}}}}

# %%
totales
# Out:
# 4654
