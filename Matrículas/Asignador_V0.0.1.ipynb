# %%
import pandas as pd

# %%
dfFormadores = pd.read_excel('./INPUT/DOCENTES/HORARIOS.xlsx', engine='openpyxl')

# %%
# Tomar solo los seleccionados
dfFormadores = dfFormadores[dfFormadores['Seleccionado'] == 'Y']

# %%
dfFormadores.sort_values(by='Total', inplace = True, ignore_index = True)
# Out:
# C:\Users\radou\AppData\Local\Temp/ipykernel_5212/3307306228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFormadores.sort_values(by='Total', inplace = True, ignore_index = True)

# %%
REQUERIDOS_POR_FRANJA = {
    'Jornada de la mañana (6 a.m. a 8 a.m.)': {
        'REQUERIDOS': 0,
        'MAPA': '6 a 8am'
    },
    'Jornada de la mañana (8 a.m. a 10 a.m.)':  {
        'REQUERIDOS': 0,
        'MAPA': '8 a 10am'
    },
    'Jornada de la mañana (10 a.m. a 12 m.)':  {
        'REQUERIDOS': 0,
        'MAPA': '10 a 12am'
    },
    'Jornada de la tarde (12 m. a 2 p.m.)':  {
        'REQUERIDOS': 0,
        'MAPA': '12 a 2pm'
    },
    'Jornada de la tarde (2 p.m. a 4 p.m.)':  {
        'REQUERIDOS': 0,
        'MAPA': '2 a 4pm'
    },
    'Jornada de la tarde (4 p.m. a 6 p.m.)':  {
        'REQUERIDOS': 0,
        'MAPA': '4 a 6pm'
    },
    'Jornada de la noche (6 p.m. a 8 p.m.)':  {
        'REQUERIDOS': 0,
        'MAPA': '6 a 8pm'
    },
    'Jornada de la noche (8 p.m. a 10 p.m.)':  {
        'REQUERIDOS': 0,
        'MAPA': '8 a 10pm'
    }
}a

# %%
dfFormadores
# Out:
#                              FORMADORES  6 a 8am  8 a 10am  10 a 12am  \
# 0             ALEX DAVID MORALES ACOSTA      NaN       NaN        NaN
# 1        ROGERIO ORLANDO BELTRAN CASTRO      NaN       NaN        NaN
# 2          ARIEL YEZID VILLAREAL SOLANO      NaN       NaN        NaN
# 3          CARLOS ADOLFO BELTRAN CASTRO      1.0       NaN        NaN
# 4           CARLOS ARTURO BOADA QUIJANO      NaN       1.0        NaN
# 5                ELKIN DAVID DIAZ PLATA      NaN       NaN        NaN
# 6          EDDINSON JULIAN CARRILLO YSA      NaN       NaN        NaN
# 7               ALBERTO LUIS SILVA LORA      NaN       1.0        1.0
# 8         OSCAR MAURICIO GONZALEZ GOMEZ      1.0       1.0        NaN
# 9           OMAR ANDRES BENAVIDES PRADA      NaN       NaN        NaN
# 10           MAGDA MILENA GARCIA GAMBOA      1.0       NaN        NaN
# 11            LUIS CARLOS GAMBOA GELVEZ      NaN       NaN        NaN
# ...

# %%
for franja, datos in REQUERIDOS_POR_FRANJA.items():
    for requeridos,
